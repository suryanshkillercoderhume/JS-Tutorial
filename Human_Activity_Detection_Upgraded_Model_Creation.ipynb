# %% [markdown]
# <a href="https://colab.research.google.com/github/suryanshkillercoderhume/JS-Tutorial/blob/main/Human_Activity_Detection_Upgraded_Model_Creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Download and Unzip Dataset

# %%
# Install gdown (only needs to be done once)
# !pip install -q gdown

# Download the file from Google Drive
# !gdown 1czfiPrNW8RJwzce6RzKLC_HDCItBEVVN -O Dataset.zip

# (Optional) Unzip the downloaded file
# !unzip Dataset.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1czfiPrNW8RJwzce6RzKLC_HDCItBEVVN
# From (redirected): https://drive.google.com/uc?id=1czfiPrNW8RJwzce6RzKLC_HDCItBEVVN&confirm=t&uuid=a39bc85e-43bf-4775-a62d-523423bcea8a
# To: /content/Dataset.zip
# 100% 43.7M/43.7M [00:01<00:00, 40.2MB/s]
# Archive:  Dataset.zip
#   inflating: Dataset/accident/RoadAccidents019_x264_12.mp4
#   inflating: Dataset/accident/RoadAccidents018_x264_12.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_5.mp4
#   inflating: Dataset/accident/RoadAccidents016_x264_10.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_19.mp4
#   inflating: Dataset/accident/RoadAccidents018_x264_17.mp4
#   inflating: Dataset/accident/RoadAccidents020_x264_1.mp4
#   inflating: Dataset/accident/RoadAccidents020_x264_10.mp4
#   inflating: Dataset/accident/RoadAccidents018_x264_13.mp4
#   inflating: Dataset/accident/RoadAccidents020_x264_9.mp4
#   inflating: Dataset/accident/RoadAccidents020_x264_2.mp4
#   inflating: Dataset/accident/RoadAccidents001_x264_8.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_15.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_31.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_9.mp4
#   inflating: Dataset/accident/RoadAccidents018_x264_21.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_20.mp4
#   inflating: Dataset/accident/RoadAccidents020_x264_6.mp4
#   inflating: Dataset/accident/RoadAccidents013_x264_16.mp4
#   inflating: Dataset/accident/RoadAccidents018_x264_30.mp4
#   inflating: Dataset/accident/RoadAccidents001_x264_14.mp4
#   inflating: Dataset/accident/RoadAccidents018_x264_20.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_8.mp4
#   inflating: Dataset/accident/RoadAccidents018_x264_11.mp4
#   inflating: Dataset/accident/RoadAccidents008_x264_9.mp4
#   inflating: Dataset/accident/RoadAccidents008_x264_8.mp4
#   inflating: Dataset/accident/RoadAccidents018_x264_25.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_30.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_13.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_26.mp4
#   inflating: Dataset/accident/RoadAccidents015_x264_21.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_27.mp4
#   inflating: Dataset/accident/RoadAccidents020_x264_3.mp4
#   inflating: Dataset/accident/RoadAccidents020_x264_13.mp4
#   inflating: Dataset/accident/RoadAccidents018_x264_29.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_18.mp4
#   inflating: Dataset/accident/RoadAccidents020_x264_12.mp4
#   inflating: Dataset/accident/RoadAccidents018_x264_27.mp4
#   inflating: Dataset/accident/RoadAccidents018_x264_19.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_21.mp4
#   inflating: Dataset/accident/RoadAccidents001_x264_20.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_17.mp4
#   inflating: Dataset/accident/RoadAccidents008_x264_11.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_4.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_29.mp4
#   inflating: Dataset/accident/RoadAccidents007_x264_9.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_3.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_24.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_0.mp4
#   inflating: Dataset/accident/RoadAccidents006_x264_4.mp4
#   inflating: Dataset/accident/RoadAccidents006_x264_3.mp4
#   inflating: Dataset/accident/RoadAccidents011_x264_4.mp4
#   inflating: Dataset/accident/RoadAccidents018_x264_26.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_25.mp4
#   inflating: Dataset/accident/RoadAccidents020_x264_5.mp4
#   inflating: Dataset/accident/RoadAccidents018_x264_18.mp4
#   inflating: Dataset/accident/RoadAccidents018_x264_24.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_10.mp4
#   inflating: Dataset/accident/RoadAccidents003_x264_8.mp4
#   inflating: Dataset/accident/RoadAccidents013_x264_14.mp4
#   inflating: Dataset/accident/RoadAccidents020_x264_4.mp4
#   inflating: Dataset/accident/RoadAccidents003_x264_10.mp4
#   inflating: Dataset/accident/RoadAccidents018_x264_28.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_28.mp4
#   inflating: Dataset/accident/RoadAccidents015_x264_23.mp4
#   inflating: Dataset/accident/RoadAccidents018_x264_22.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_16.mp4
#   inflating: Dataset/accident/RoadAccidents020_x264_0.mp4
#   inflating: Dataset/accident/RoadAccidents007_x264_10.mp4
#   inflating: Dataset/accident/RoadAccidents020_x264_7.mp4
#   inflating: Dataset/accident/RoadAccidents001_x264_12.mp4
#   inflating: Dataset/accident/RoadAccidents013_x264_13.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_1.mp4
#   inflating: Dataset/accident/RoadAccidents008_x264_7.mp4
#   inflating: Dataset/accident/RoadAccidents020_x264_11.mp4
#   inflating: Dataset/accident/RoadAccidents008_x264_10.mp4
#   inflating: Dataset/accident/RoadAccidents016_x264_11.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_11.mp4
#   inflating: Dataset/accident/RoadAccidents018_x264_23.mp4
#   inflating: Dataset/accident/RoadAccidents020_x264_8.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_23.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_6.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_7.mp4
#   inflating: Dataset/accident/RoadAccidents003_x264_9.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_22.mp4
#   inflating: Dataset/fighting/Fighting003_x264_13.mp4
#   inflating: Dataset/accident/RoadAccidents015_x264_22.mp4
#   inflating: Dataset/accident/RoadAccidents011_x264_5.mp4
#   inflating: Dataset/accident/RoadAccidents013_x264_15.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_2.mp4
#   inflating: Dataset/accident/RoadAccidents001_x264_9.mp4
#   inflating: Dataset/accident/RoadAccidents018_x264_16.mp4
#   inflating: Dataset/fighting/Fighting007_x264_28.mp4
#   inflating: Dataset/fighting/Fighting005_x264_4.mp4
#   inflating: Dataset/fighting/Fighting005_x264_20.mp4
#   inflating: Dataset/fighting/Fighting003_x264_16.mp4
#   inflating: Dataset/fighting/Fighting007_x264_19.mp4
#   inflating: Dataset/fighting/Fighting007_x264_4.mp4
#   inflating: Dataset/accident/RoadAccidents016_x264_9.mp4
#   inflating: Dataset/fighting/Fighting005_x264_0.mp4
#   inflating: Dataset/fighting/Fighting007_x264_7.mp4
#   inflating: Dataset/accident/RoadAccidents018_x264_31.mp4
#   inflating: Dataset/fighting/Fighting005_x264_15.mp4
#   inflating: Dataset/fighting/Fighting007_x264_27.mp4
#   inflating: Dataset/fighting/Fighting007_x264_0.mp4
#   inflating: Dataset/fighting/Fighting005_x264_25.mp4
#   inflating: Dataset/fighting/Fighting005_x264_16.mp4
#   inflating: Dataset/fighting/Fighting005_x264_5.mp4
#   inflating: Dataset/fighting/Fighting002_x264_15.mp4
#   inflating: Dataset/fighting/Fighting003_x264_8.mp4
#   inflating: Dataset/fighting/Fighting005_x264_23.mp4
#   inflating: Dataset/fighting/Fighting009_x264_7.mp4
#   inflating: Dataset/accident/RoadAccidents018_x264_15.mp4
#   inflating: Dataset/fighting/Fighting005_x264_13.mp4
#   inflating: Dataset/fighting/Fighting003_x264_14.mp4
#   inflating: Dataset/fighting/Fighting007_x264_10.mp4
#   inflating: Dataset/fighting/Fighting002_x264_25.mp4
#   inflating: Dataset/fighting/Fighting003_x264_19.mp4
#   inflating: Dataset/fighting/Fighting003_x264_4.mp4
#   inflating: Dataset/accident/RoadAccidents013_x264_17.mp4
#   inflating: Dataset/fighting/Fighting003_x264_0.mp4
#   inflating: Dataset/fighting/Fighting002_x264_17.mp4
#   inflating: Dataset/fighting/Fighting002_x264_14.mp4
#   inflating: Dataset/fighting/Fighting002_x264_23.mp4
#   inflating: Dataset/fighting/Fighting003_x264_7.mp4
#   inflating: Dataset/fighting/Fighting005_x264_7.mp4
#   inflating: Dataset/fighting/Fighting005_x264_3.mp4
#   inflating: Dataset/fighting/Fighting003_x264_1.mp4
#   inflating: Dataset/fighting/Fighting003_x264_11.mp4
#   inflating: Dataset/fighting/Fighting005_x264_10.mp4
#   inflating: Dataset/fighting/Fighting005_x264_8.mp4
#   inflating: Dataset/fighting/Fighting003_x264_18.mp4
#   inflating: Dataset/fighting/Fighting002_x264_16.mp4
#   inflating: Dataset/fighting/Fighting007_x264_31.mp4
#   inflating: Dataset/fighting/Fighting007_x264_8.mp4
#   inflating: Dataset/fighting/Fighting005_x264_6.mp4
#   inflating: Dataset/fighting/Fighting002_x264_12.mp4
#   inflating: Dataset/fighting/Fighting003_x264_29.mp4
#   inflating: Dataset/fighting/Fighting003_x264_31.mp4
#   inflating: Dataset/fighting/Fighting002_x264_7.mp4
#   inflating: Dataset/fighting/Fighting002_x264_6.mp4
#   inflating: Dataset/fighting/Fighting009_x264_12.mp4
#   inflating: Dataset/fighting/Fighting009_x264_13.mp4
#   inflating: Dataset/fighting/Fighting002_x264_8.mp4
#   inflating: Dataset/fighting/Fighting002_x264_31.mp4
#   inflating: Dataset/fighting/Fighting003_x264_9.mp4
#   inflating: Dataset/accident/RoadAccidents019_x264_14.mp4
#   inflating: Dataset/fighting/Fighting009_x264_4.mp4
#   inflating: Dataset/accident/RoadAccidents018_x264_14.mp4
#   inflating: Dataset/fighting/Fighting007_x264_5.mp4
#   inflating: Dataset/fighting/Fighting002_x264_13.mp4
#   inflating: Dataset/fighting/Fighting002_x264_1.mp4
#   inflating: Dataset/fighting/Fighting005_x264_18.mp4
#   inflating: Dataset/fighting/Fighting009_x264_9.mp4
#   inflating: Dataset/fighting/Fighting009_x264_15.mp4
#   inflating: Dataset/fighting/Fighting002_x264_18.mp4
#   inflating: Dataset/fighting/Fighting005_x264_12.mp4
#   inflating: Dataset/fighting/Fighting003_x264_2.mp4
#   inflating: Dataset/fighting/Fighting002_x264_9.mp4
#   inflating: Dataset/fighting/Fighting003_x264_6.mp4
#   inflating: Dataset/fighting/Fighting002_x264_21.mp4
#   inflating: Dataset/fighting/Fighting003_x264_28.mp4
#   inflating: Dataset/fighting/Fighting002_x264_24.mp4
#   inflating: Dataset/fighting/Fighting007_x264_3.mp4
#   inflating: Dataset/fighting/Fighting009_x264_8.mp4
#   inflating: Dataset/fighting/Fighting002_x264_10.mp4
#   inflating: Dataset/fighting/Fighting005_x264_9.mp4
#   inflating: Dataset/fighting/Fighting009_x264_16.mp4
#   inflating: Dataset/fighting/Fighting009_x264_14.mp4
#   inflating: Dataset/fighting/Fighting005_x264_31.mp4
#   inflating: Dataset/fighting/Fighting002_x264_2.mp4
#   inflating: Dataset/fighting/Fighting005_x264_24.mp4
#   inflating: Dataset/fighting/Fighting009_x264_1.mp4
#   inflating: Dataset/fighting/Fighting005_x264_29.mp4
#   inflating: Dataset/fighting/Fighting003_x264_17.mp4
#   inflating: Dataset/fighting/Fighting007_x264_22.mp4
#   inflating: Dataset/fighting/Fighting005_x264_22.mp4
#   inflating: Dataset/fighting/Fighting007_x264_12.mp4
#   inflating: Dataset/fighting/Fighting002_x264_0.mp4
#   inflating: Dataset/fighting/Fighting007_x264_21.mp4
#   inflating: Dataset/fighting/Fighting002_x264_5.mp4
#   inflating: Dataset/fighting/Fighting007_x264_13.mp4
#   inflating: Dataset/fighting/Fighting007_x264_11.mp4
#   inflating: Dataset/fighting/Fighting007_x264_1.mp4
#   inflating: Dataset/fighting/Fighting007_x264_6.mp4
#   inflating: Dataset/fighting/Fighting009_x264_2.mp4
#   inflating: Dataset/fighting/Fighting005_x264_11.mp4
#   inflating: Dataset/fighting/Fighting002_x264_29.mp4
#   inflating: Dataset/fighting/Fighting002_x264_30.mp4
#   inflating: Dataset/fighting/Fighting007_x264_2.mp4
#   inflating: Dataset/fighting/Fighting002_x264_27.mp4
#   inflating: Dataset/fighting/Fighting003_x264_5.mp4
#   inflating: Dataset/fighting/Fighting007_x264_23.mp4
#   inflating: Dataset/fighting/Fighting009_x264_5.mp4
#   inflating: Dataset/fighting/Fighting009_x264_17.mp4
#   inflating: Dataset/fighting/Fighting005_x264_27.mp4
#   inflating: Dataset/fighting/Fighting007_x264_29.mp4
#   inflating: Dataset/fighting/Fighting003_x264_12.mp4
#   inflating: Dataset/fighting/Fighting003_x264_25.mp4
#   inflating: Dataset/fighting/Fighting003_x264_10.mp4
#   inflating: Dataset/fighting/Fighting007_x264_30.mp4
#   inflating: Dataset/fighting/Fighting003_x264_27.mp4
#   inflating: Dataset/fighting/Fighting005_x264_19.mp4
#   inflating: Dataset/fighting/Fighting002_x264_26.mp4
#   inflating: Dataset/fighting/Fighting003_x264_3.mp4
#   inflating: Dataset/fighting/Fighting005_x264_28.mp4
#   inflating: Dataset/fighting/Fighting009_x264_11.mp4
#   inflating: Dataset/fighting/Fighting009_x264_10.mp4
#   inflating: Dataset/fighting/Fighting007_x264_26.mp4
#   inflating: Dataset/fighting/Fighting009_x264_6.mp4
#   inflating: Dataset/fighting/Fighting002_x264_20.mp4
#   inflating: Dataset/fighting/Fighting005_x264_17.mp4
#   inflating: Dataset/fighting/Fighting007_x264_18.mp4
#   inflating: Dataset/fighting/Fighting005_x264_26.mp4
#   inflating: Dataset/fighting/Fighting003_x264_30.mp4
#   inflating: Dataset/fighting/Fighting002_x264_28.mp4
#   inflating: Dataset/fighting/Fighting005_x264_1.mp4
#   inflating: Dataset/fighting/Fighting005_x264_21.mp4
#   inflating: Dataset/fighting/Fighting005_x264_2.mp4
#   inflating: Dataset/fighting/Fighting005_x264_30.mp4
#   inflating: Dataset/fighting/Fighting007_x264_15.mp4
#   inflating: Dataset/fighting/Fighting002_x264_4.mp4
#   inflating: Dataset/fighting/Fighting009_x264_3.mp4
#   inflating: Dataset/fighting/Fighting009_x264_18.mp4
#   inflating: Dataset/fighting/Fighting002_x264_22.mp4
#   inflating: Dataset/shooting/Shooting015_x264_20.mp4
#   inflating: Dataset/fighting/Fighting002_x264_11.mp4
#   inflating: Dataset/fighting/Fighting002_x264_3.mp4
#   inflating: Dataset/shooting/Shooting015_x264_0.mp4
#   inflating: Dataset/fighting/Fighting002_x264_19.mp4
#   inflating: Dataset/shooting/Shooting013_x264_5.mp4
#   inflating: Dataset/fighting/Fighting005_x264_14.mp4
#   inflating: Dataset/shooting/Shooting013_x264_28.mp4
#   inflating: Dataset/shooting/Shooting011_x264_30.mp4
#   inflating: Dataset/shooting/Shooting011_x264_6.mp4
#   inflating: Dataset/shooting/Shooting015_x264_1.mp4
#   inflating: Dataset/fighting/Fighting009_x264_0.mp4
#   inflating: Dataset/fighting/Fighting003_x264_15.mp4
#   inflating: Dataset/shooting/Shooting015_x264_28.mp4
#   inflating: Dataset/shooting/Shooting011_x264_3.mp4
#   inflating: Dataset/shooting/Shooting011_x264_31.mp4
#   inflating: Dataset/shooting/Shooting010_x264_31.mp4
#   inflating: Dataset/shooting/Shooting013_x264_3.mp4
#   inflating: Dataset/shooting/Shooting013_x264_4.mp4
#   inflating: Dataset/shooting/Shooting011_x264_20.mp4
#   inflating: Dataset/shooting/Shooting015_x264_11.mp4
#   inflating: Dataset/shooting/Shooting011_x264_27.mp4
#   inflating: Dataset/shooting/Shooting011_x264_23.mp4
#   inflating: Dataset/shooting/Shooting011_x264_2.mp4
#   inflating: Dataset/shooting/Shooting015_x264_9.mp4
#   inflating: Dataset/shooting/Shooting010_x264_28.mp4
#   inflating: Dataset/shooting/Shooting015_x264_3.mp4
#   inflating: Dataset/shooting/Shooting011_x264_7.mp4
#   inflating: Dataset/shooting/Shooting013_x264_9.mp4
#   inflating: Dataset/shooting/Shooting010_x264_29.mp4
#   inflating: Dataset/shooting/Shooting013_x264_18.mp4
#   inflating: Dataset/shooting/Shooting015_x264_6.mp4
#   inflating: Dataset/shooting/Shooting011_x264_11.mp4
#   inflating: Dataset/shooting/Shooting013_x264_29.mp4
#   inflating: Dataset/shooting/Shooting015_x264_13.mp4
#   inflating: Dataset/shooting/Shooting013_x264_7.mp4
#   inflating: Dataset/shooting/Shooting011_x264_4.mp4
#   inflating: Dataset/shooting/Shooting010_x264_5.mp4
#   inflating: Dataset/shooting/Shooting015_x264_23.mp4
#   inflating: Dataset/fighting/Fighting007_x264_9.mp4
#   inflating: Dataset/shooting/Shooting013_x264_14.mp4
#   inflating: Dataset/shooting/Shooting015_x264_21.mp4
#   inflating: Dataset/shooting/Shooting018_x264_6.mp4
#   inflating: Dataset/shooting/Shooting015_x264_19.mp4
#   inflating: Dataset/shooting/Shooting018_x264_2.mp4
#   inflating: Dataset/shooting/Shooting018_x264_0.mp4
#   inflating: Dataset/shooting/Shooting018_x264_3.mp4
#   inflating: Dataset/shooting/Shooting018_x264_4.mp4
#   inflating: Dataset/shooting/Shooting015_x264_30.mp4
#   inflating: Dataset/shooting/Shooting011_x264_21.mp4
#   inflating: Dataset/shooting/Shooting013_x264_8.mp4
#   inflating: Dataset/shooting/Shooting013_x264_26.mp4
#   inflating: Dataset/shooting/Shooting015_x264_24.mp4
#   inflating: Dataset/shooting/Shooting015_x264_12.mp4
#   inflating: Dataset/shooting/Shooting010_x264_27.mp4
#   inflating: Dataset/shooting/Shooting018_x264_5.mp4
#   inflating: Dataset/shooting/Shooting013_x264_15.mp4
#   inflating: Dataset/shooting/Shooting011_x264_19.mp4
#   inflating: Dataset/shooting/Shooting011_x264_12.mp4
#   inflating: Dataset/shooting/Shooting010_x264_4.mp4
#   inflating: Dataset/shooting/Shooting011_x264_22.mp4
#   inflating: Dataset/shooting/Shooting013_x264_22.mp4
#   inflating: Dataset/shooting/Shooting015_x264_29.mp4
#   inflating: Dataset/shooting/Shooting011_x264_13.mp4
#   inflating: Dataset/shooting/Shooting013_x264_10.mp4
#   inflating: Dataset/shooting/Shooting011_x264_18.mp4
#   inflating: Dataset/shooting/Shooting011_x264_8.mp4
#   inflating: Dataset/shooting/Shooting015_x264_17.mp4
#   inflating: Dataset/shooting/Shooting010_x264_9.mp4
#   inflating: Dataset/shooting/Shooting010_x264_30.mp4
#   inflating: Dataset/shooting/Shooting013_x264_2.mp4
#   inflating: Dataset/shooting/Shooting013_x264_27.mp4
#   inflating: Dataset/shooting/Shooting013_x264_23.mp4
#   inflating: Dataset/shooting/Shooting013_x264_0.mp4
#   inflating: Dataset/shooting/Shooting015_x264_16.mp4
#   inflating: Dataset/shooting/Shooting010_x264_8.mp4
#   inflating: Dataset/shooting/Shooting013_x264_30.mp4
#   inflating: Dataset/shooting/Shooting010_x264_3.mp4
#   inflating: Dataset/shooting/Shooting013_x264_21.mp4
#   inflating: Dataset/shooting/Shooting011_x264_1.mp4
#   inflating: Dataset/shooting/Shooting011_x264_29.mp4
#   inflating: Dataset/shooting/Shooting015_x264_15.mp4
#   inflating: Dataset/shooting/Shooting013_x264_11.mp4
#   inflating: Dataset/shooting/Shooting011_x264_25.mp4
#   inflating: Dataset/shooting/Shooting015_x264_4.mp4
#   inflating: Dataset/shooting/Shooting011_x264_14.mp4
#   inflating: Dataset/shooting/Shooting015_x264_5.mp4
#   inflating: Dataset/shooting/Shooting015_x264_7.mp4
#   inflating: Dataset/shooting/Shooting013_x264_20.mp4
#   inflating: Dataset/shooting/Shooting015_x264_31.mp4
#   inflating: Dataset/shooting/Shooting015_x264_22.mp4
#   inflating: Dataset/shooting/Shooting011_x264_9.mp4
#   inflating: Dataset/shooting/Shooting015_x264_18.mp4
#   inflating: Dataset/shooting/Shooting013_x264_24.mp4
#   inflating: Dataset/shooting/Shooting013_x264_13.mp4
#   inflating: Dataset/shooting/Shooting015_x264_27.mp4
#   inflating: Dataset/shooting/Shooting013_x264_25.mp4
#   inflating: Dataset/shooting/Shooting010_x264_6.mp4
#   inflating: Dataset/shooting/Shooting010_x264_7.mp4
#   inflating: Dataset/shooting/Shooting013_x264_6.mp4
#   inflating: Dataset/shooting/Shooting011_x264_24.mp4
#   inflating: Dataset/shooting/Shooting011_x264_15.mp4
#   inflating: Dataset/shooting/Shooting018_x264_1.mp4
#   inflating: Dataset/shooting/Shooting015_x264_8.mp4
#   inflating: Dataset/shooting/Shooting013_x264_19.mp4
#   inflating: Dataset/shooting/Shooting011_x264_17.mp4
#   inflating: Dataset/shooting/Shooting011_x264_10.mp4
#   inflating: Dataset/shooting/Shooting011_x264_5.mp4
#   inflating: Dataset/shooting/Shooting013_x264_1.mp4
#   inflating: Dataset/shooting/Shooting011_x264_0.mp4
#   inflating: Dataset/shooting/Shooting015_x264_26.mp4
#   inflating: Dataset/shooting/Shooting009_x264_10.mp4
#   inflating: Dataset/shooting/Shooting013_x264_12.mp4
#   inflating: Dataset/shooting/Shooting007_x264_2.mp4
#   inflating: Dataset/shooting/Shooting011_x264_16.mp4
#   inflating: Dataset/shooting/Shooting007_x264_30.mp4
#   inflating: Dataset/shooting/Shooting018_x264_7.mp4
#   inflating: Dataset/shooting/Shooting009_x264_25.mp4
#   inflating: Dataset/shooting/Shooting002_x264_21.mp4
#   inflating: Dataset/shooting/Shooting005_x264_7.mp4
#   inflating: Dataset/shooting/Shooting002_x264_3.mp4
#   inflating: Dataset/shooting/Shooting013_x264_17.mp4
#   inflating: Dataset/shooting/Shooting011_x264_26.mp4
#   inflating: Dataset/shooting/Shooting013_x264_16.mp4
#   inflating: Dataset/shooting/Shooting008_x264_27.mp4
#   inflating: Dataset/shooting/Shooting011_x264_28.mp4
#   inflating: Dataset/shooting/Shooting015_x264_2.mp4
#   inflating: Dataset/shooting/Shooting002_x264_11.mp4
#   inflating: Dataset/shooting/Shooting010_x264_18.mp4
#   inflating: Dataset/shooting/Shooting013_x264_31.mp4
#   inflating: Dataset/shooting/Shooting008_x264_0.mp4
#   inflating: Dataset/shooting/Shooting008_x264_20.mp4
#   inflating: Dataset/shooting/Shooting008_x264_16.mp4
#   inflating: Dataset/shooting/Shooting007_x264_9.mp4
#   inflating: Dataset/shooting/Shooting010_x264_15.mp4
#   inflating: Dataset/shooting/Shooting010_x264_11.mp4
#   inflating: Dataset/shooting/Shooting002_x264_5.mp4
#   inflating: Dataset/shooting/Shooting005_x264_9.mp4
#   inflating: Dataset/shooting/Shooting009_x264_1.mp4
#   inflating: Dataset/shooting/Shooting008_x264_13.mp4
#   inflating: Dataset/shooting/Shooting002_x264_23.mp4
#   inflating: Dataset/shooting/Shooting002_x264_28.mp4
#   inflating: Dataset/shooting/Shooting005_x264_11.mp4
#   inflating: Dataset/shooting/Shooting005_x264_13.mp4
#   inflating: Dataset/shooting/Shooting002_x264_15.mp4
#   inflating: Dataset/shooting/Shooting009_x264_29.mp4
#   inflating: Dataset/shooting/Shooting009_x264_5.mp4
#   inflating: Dataset/shooting/Shooting007_x264_12.mp4
#   inflating: Dataset/shooting/Shooting010_x264_24.mp4
#   inflating: Dataset/shooting/Shooting015_x264_14.mp4
#   inflating: Dataset/shooting/Shooting015_x264_10.mp4
#   inflating: Dataset/shooting/Shooting007_x264_26.mp4
#   inflating: Dataset/shooting/Shooting015_x264_25.mp4
#   inflating: Dataset/shooting/Shooting002_x264_31.mp4
#   inflating: Dataset/shooting/Shooting008_x264_14.mp4
#   inflating: Dataset/shooting/Shooting005_x264_8.mp4
#   inflating: Dataset/shooting/Shooting007_x264_25.mp4
#   inflating: Dataset/shooting/Shooting007_x264_29.mp4
#   inflating: Dataset/shooting/Shooting010_x264_22.mp4
#   inflating: Dataset/shooting/Shooting002_x264_19.mp4
#   inflating: Dataset/shooting/Shooting007_x264_17.mp4
#   inflating: Dataset/shooting/Shooting005_x264_10.mp4
#   inflating: Dataset/shooting/Shooting005_x264_25.mp4
#   inflating: Dataset/shooting/Shooting009_x264_3.mp4
#   inflating: Dataset/shooting/Shooting005_x264_16.mp4
#   inflating: Dataset/shooting/Shooting005_x264_15.mp4
#   inflating: Dataset/shooting/Shooting007_x264_3.mp4
#   inflating: Dataset/shooting/Shooting007_x264_27.mp4
#   inflating: Dataset/shooting/Shooting009_x264_2.mp4
#   inflating: Dataset/shooting/Shooting005_x264_27.mp4
#   inflating: Dataset/shooting/Shooting005_x264_30.mp4
#   inflating: Dataset/shooting/Shooting009_x264_16.mp4
#   inflating: Dataset/shooting/Shooting007_x264_6.mp4
#   inflating: Dataset/shooting/Shooting010_x264_26.mp4
#   inflating: Dataset/shooting/Shooting007_x264_4.mp4
#   inflating: Dataset/shooting/Shooting007_x264_31.mp4
#   inflating: Dataset/shooting/Shooting010_x264_1.mp4
#   inflating: Dataset/shooting/Shooting008_x264_31.mp4
#   inflating: Dataset/shooting/Shooting007_x264_20.mp4
#   inflating: Dataset/shooting/Shooting009_x264_7.mp4
#   inflating: Dataset/shooting/Shooting007_x264_28.mp4
#   inflating: Dataset/shooting/Shooting009_x264_26.mp4
#   inflating: Dataset/shooting/Shooting005_x264_26.mp4
#   inflating: Dataset/shooting/Shooting008_x264_22.mp4
#   inflating: Dataset/shooting/Shooting008_x264_5.mp4
#   inflating: Dataset/shooting/Shooting002_x264_4.mp4
#   inflating: Dataset/shooting/Shooting008_x264_21.mp4
#   inflating: Dataset/shooting/Shooting007_x264_13.mp4
#   inflating: Dataset/shooting/Shooting002_x264_20.mp4
#   inflating: Dataset/shooting/Shooting002_x264_18.mp4
#   inflating: Dataset/shooting/Shooting009_x264_20.mp4
#   inflating: Dataset/shooting/Shooting005_x264_4.mp4
#   inflating: Dataset/shooting/Shooting002_x264_16.mp4
#   inflating: Dataset/shooting/Shooting002_x264_14.mp4
#   inflating: Dataset/shooting/Shooting008_x264_25.mp4
#   inflating: Dataset/shooting/Shooting005_x264_29.mp4
#   inflating: Dataset/shooting/Shooting009_x264_23.mp4
#   inflating: Dataset/shooting/Shooting009_x264_17.mp4
#   inflating: Dataset/shooting/Shooting010_x264_25.mp4
#   inflating: Dataset/shooting/Shooting010_x264_13.mp4
#   inflating: Dataset/shooting/Shooting002_x264_12.mp4
#   inflating: Dataset/shooting/Shooting007_x264_11.mp4
#   inflating: Dataset/shooting/Shooting002_x264_27.mp4
#   inflating: Dataset/shooting/Shooting008_x264_4.mp4
#   inflating: Dataset/shooting/Shooting002_x264_2.mp4
#   inflating: Dataset/shooting/Shooting009_x264_28.mp4
#   inflating: Dataset/shooting/Shooting002_x264_10.mp4
#   inflating: Dataset/shooting/Shooting002_x264_25.mp4
#   inflating: Dataset/shooting/Shooting007_x264_5.mp4
#   inflating: Dataset/shooting/Shooting009_x264_31.mp4
#   inflating: Dataset/shooting/Shooting007_x264_18.mp4
#   inflating: Dataset/shooting/Shooting008_x264_15.mp4
#   inflating: Dataset/shooting/Shooting005_x264_22.mp4
#   inflating: Dataset/shooting/Shooting007_x264_19.mp4
#   inflating: Dataset/shooting/Shooting005_x264_3.mp4
#   inflating: Dataset/shooting/Shooting007_x264_23.mp4
#   inflating: Dataset/shooting/Shooting009_x264_27.mp4
#   inflating: Dataset/shooting/Shooting009_x264_11.mp4
#   inflating: Dataset/shooting/Shooting002_x264_26.mp4
#   inflating: Dataset/shooting/Shooting007_x264_22.mp4
#   inflating: Dataset/shooting/Shooting005_x264_14.mp4
#   inflating: Dataset/shooting/Shooting002_x264_13.mp4
#   inflating: Dataset/shooting/Shooting007_x264_24.mp4
#   inflating: Dataset/shooting/Shooting005_x264_28.mp4
#   inflating: Dataset/shooting/Shooting008_x264_17.mp4
#   inflating: Dataset/shooting/Shooting002_x264_17.mp4
#   inflating: Dataset/shooting/Shooting010_x264_0.mp4
#   inflating: Dataset/shooting/Shooting008_x264_10.mp4
#   inflating: Dataset/shooting/Shooting002_x264_30.mp4
#   inflating: Dataset/shooting/Shooting005_x264_1.mp4
#   inflating: Dataset/shooting/Shooting010_x264_17.mp4
#   inflating: Dataset/shooting/Shooting002_x264_0.mp4
#   inflating: Dataset/shooting/Shooting002_x264_24.mp4
#   inflating: Dataset/shooting/Shooting010_x264_12.mp4
#   inflating: Dataset/shooting/Shooting005_x264_23.mp4
#   inflating: Dataset/shooting/Shooting007_x264_21.mp4
#   inflating: Dataset/shooting/Shooting010_x264_10.mp4
#   inflating: Dataset/shooting/Shooting009_x264_0.mp4
#   inflating: Dataset/shooting/Shooting007_x264_10.mp4
#   inflating: Dataset/shooting/Shooting005_x264_31.mp4
#   inflating: Dataset/shooting/Shooting009_x264_21.mp4
#   inflating: Dataset/shooting/Shooting008_x264_11.mp4
#   inflating: Dataset/shooting/Shooting007_x264_0.mp4
#   inflating: Dataset/shooting/Shooting008_x264_18.mp4
#   inflating: Dataset/shooting/Shooting009_x264_14.mp4
#   inflating: Dataset/shooting/Shooting002_x264_9.mp4
#   inflating: Dataset/explosion/Explosion011_x264_28.mp4
#   inflating: Dataset/shooting/Shooting008_x264_12.mp4
#   inflating: Dataset/shooting/Shooting005_x264_2.mp4
#   inflating: Dataset/explosion/Explosion013_x264_19.mp4
#   inflating: Dataset/explosion/Explosion011_x264_9.mp4
#   inflating: Dataset/explosion/Explosion011_x264_16.mp4
#   inflating: Dataset/explosion/Explosion017_x264_17.mp4
#   inflating: Dataset/explosion/Explosion017_x264_22.mp4
#   inflating: Dataset/shooting/Shooting009_x264_22.mp4
#   inflating: Dataset/explosion/Explosion017_x264_30.mp4
#   inflating: Dataset/shooting/Shooting009_x264_24.mp4
#   inflating: Dataset/shooting/Shooting010_x264_23.mp4
#   inflating: Dataset/explosion/Explosion013_x264_5.mp4
#   inflating: Dataset/explosion/Explosion017_x264_28.mp4
#   inflating: Dataset/shooting/Shooting007_x264_1.mp4
#   inflating: Dataset/shooting/Shooting009_x264_6.mp4
#   inflating: Dataset/explosion/Explosion009_x264_5.mp4
#   inflating: Dataset/shooting/Shooting002_x264_8.mp4
#   inflating: Dataset/explosion/Explosion011_x264_1.mp4
#   inflating: Dataset/explosion/Explosion017_x264_9.mp4
#   inflating: Dataset/explosion/Explosion017_x264_26.mp4
#   inflating: Dataset/explosion/Explosion009_x264_15.mp4
#   inflating: Dataset/explosion/Explosion020_x264_4.mp4
#   inflating: Dataset/shooting/Shooting002_x264_7.mp4
#   inflating: Dataset/explosion/Explosion009_x264_17.mp4
#   inflating: Dataset/explosion/Explosion011_x264_15.mp4
#   inflating: Dataset/explosion/Explosion013_x264_25.mp4
#   inflating: Dataset/explosion/Explosion013_x264_1.mp4
#   inflating: Dataset/explosion/Explosion011_x264_0.mp4
#   inflating: Dataset/explosion/Explosion017_x264_1.mp4
#   inflating: Dataset/explosion/Explosion009_x264_20.mp4
#   inflating: Dataset/explosion/Explosion009_x264_16.mp4
#   inflating: Dataset/explosion/Explosion017_x264_4.mp4
#   inflating: Dataset/explosion/Explosion014_x264_12.mp4
#   inflating: Dataset/explosion/Explosion008_x264_6.mp4
#   inflating: Dataset/explosion/Explosion014_x264_5.mp4
#   inflating: Dataset/explosion/Explosion013_x264_17.mp4
#   inflating: Dataset/explosion/Explosion011_x264_8.mp4
#   inflating: Dataset/explosion/Explosion009_x264_27.mp4
#   inflating: Dataset/explosion/Explosion011_x264_4.mp4
#   inflating: Dataset/explosion/Explosion013_x264_20.mp4
#   inflating: Dataset/explosion/Explosion013_x264_15.mp4
#   inflating: Dataset/explosion/Explosion009_x264_14.mp4
#   inflating: Dataset/shooting/Shooting005_x264_21.mp4
#   inflating: Dataset/explosion/Explosion011_x264_5.mp4
#   inflating: Dataset/explosion/Explosion014_x264_7.mp4
#   inflating: Dataset/explosion/Explosion013_x264_6.mp4
#   inflating: Dataset/explosion/Explosion020_x264_2.mp4
#   inflating: Dataset/explosion/Explosion017_x264_13.mp4
#   inflating: Dataset/explosion/Explosion013_x264_0.mp4
#   inflating: Dataset/explosion/Explosion009_x264_22.mp4
#   inflating: Dataset/explosion/Explosion013_x264_4.mp4
#   inflating: Dataset/explosion/Explosion011_x264_24.mp4
#   inflating: Dataset/explosion/Explosion009_x264_11.mp4
#   inflating: Dataset/explosion/Explosion011_x264_26.mp4
#   inflating: Dataset/explosion/Explosion011_x264_25.mp4
#   inflating: Dataset/explosion/Explosion013_x264_12.mp4
#   inflating: Dataset/explosion/Explosion014_x264_1.mp4
#   inflating: Dataset/explosion/Explosion014_x264_13.mp4
#   inflating: Dataset/explosion/Explosion017_x264_14.mp4
#   inflating: Dataset/explosion/Explosion014_x264_26.mp4
#   inflating: Dataset/explosion/Explosion013_x264_27.mp4
#   inflating: Dataset/explosion/Explosion013_x264_10.mp4
#   inflating: Dataset/explosion/Explosion014_x264_0.mp4
#   inflating: Dataset/explosion/Explosion011_x264_12.mp4
#   inflating: Dataset/explosion/Explosion017_x264_7.mp4
#   inflating: Dataset/explosion/Explosion014_x264_15.mp4
#   inflating: Dataset/explosion/Explosion013_x264_2.mp4
#   inflating: Dataset/explosion/Explosion011_x264_27.mp4
#   inflating: Dataset/explosion/Explosion014_x264_20.mp4
#   inflating: Dataset/explosion/Explosion009_x264_30.mp4
#   inflating: Dataset/explosion/Explosion013_x264_18.mp4
#   inflating: Dataset/explosion/Explosion011_x264_3.mp4
#   inflating: Dataset/explosion/Explosion008_x264_8.mp4
#   inflating: Dataset/explosion/Explosion009_x264_21.mp4
#   inflating: Dataset/explosion/Explosion017_x264_5.mp4
#   inflating: Dataset/explosion/Explosion014_x264_22.mp4
#   inflating: Dataset/shooting/Shooting005_x264_19.mp4
#   inflating: Dataset/explosion/Explosion017_x264_23.mp4
#   inflating: Dataset/explosion/Explosion011_x264_10.mp4
#   inflating: Dataset/explosion/Explosion017_x264_11.mp4
#   inflating: Dataset/explosion/Explosion017_x264_0.mp4
#   inflating: Dataset/explosion/Explosion009_x264_19.mp4
#   inflating: Dataset/explosion/Explosion011_x264_7.mp4
#   inflating: Dataset/explosion/Explosion017_x264_12.mp4
#   inflating: Dataset/explosion/Explosion017_x264_31.mp4
#   inflating: Dataset/explosion/Explosion017_x264_3.mp4
#   inflating: Dataset/explosion/Explosion014_x264_4.mp4
#   inflating: Dataset/explosion/Explosion013_x264_9.mp4
#   inflating: Dataset/explosion/Explosion011_x264_30.mp4
#   inflating: Dataset/explosion/Explosion009_x264_31.mp4
#   inflating: Dataset/explosion/Explosion008_x264_7.mp4
#   inflating: Dataset/explosion/Explosion011_x264_29.mp4
#   inflating: Dataset/explosion/Explosion014_x264_27.mp4
#   inflating: Dataset/explosion/Explosion014_x264_16.mp4
#   inflating: Dataset/explosion/Explosion014_x264_8.mp4
#   inflating: Dataset/explosion/Explosion014_x264_17.mp4
#   inflating: Dataset/explosion/Explosion009_x264_28.mp4
#   inflating: Dataset/explosion/Explosion014_x264_25.mp4
#   inflating: Dataset/explosion/Explosion014_x264_30.mp4
#   inflating: Dataset/explosion/Explosion013_x264_24.mp4
#   inflating: Dataset/explosion/Explosion009_x264_29.mp4
#   inflating: Dataset/explosion/Explosion013_x264_23.mp4
#   inflating: Dataset/explosion/Explosion014_x264_24.mp4
#   inflating: Dataset/explosion/Explosion014_x264_18.mp4
#   inflating: Dataset/explosion/Explosion014_x264_10.mp4
#   inflating: Dataset/explosion/Explosion017_x264_24.mp4
#   inflating: Dataset/explosion/Explosion009_x264_23.mp4
#   inflating: Dataset/explosion/Explosion014_x264_3.mp4
#   inflating: Dataset/explosion/Explosion017_x264_20.mp4
#   inflating: Dataset/explosion/Explosion011_x264_18.mp4
#   inflating: Dataset/explosion/Explosion014_x264_2.mp4
#   inflating: Dataset/explosion/Explosion013_x264_31.mp4
#   inflating: Dataset/explosion/Explosion014_x264_31.mp4
#   inflating: Dataset/explosion/Explosion011_x264_22.mp4
#   inflating: Dataset/explosion/Explosion011_x264_14.mp4
#   inflating: Dataset/explosion/Explosion008_x264_9.mp4
#   inflating: Dataset/explosion/Explosion013_x264_21.mp4
#   inflating: Dataset/explosion/Explosion017_x264_8.mp4
#   inflating: Dataset/explosion/Explosion009_x264_12.mp4
#   inflating: Dataset/explosion/Explosion013_x264_29.mp4
#   inflating: Dataset/explosion/Explosion017_x264_16.mp4
#   inflating: Dataset/explosion/Explosion017_x264_29.mp4
#   inflating: Dataset/explosion/Explosion011_x264_20.mp4
#   inflating: Dataset/explosion/Explosion020_x264_3.mp4
#   inflating: Dataset/explosion/Explosion013_x264_3.mp4
#   inflating: Dataset/explosion/Explosion014_x264_29.mp4
#   inflating: Dataset/explosion/Explosion017_x264_27.mp4
#   inflating: Dataset/explosion/Explosion013_x264_28.mp4
#   inflating: Dataset/explosion/Explosion011_x264_23.mp4
#   inflating: Dataset/explosion/Explosion009_x264_2.mp4
#   inflating: Dataset/explosion/Explosion009_x264_13.mp4
#   inflating: Dataset/explosion/Explosion014_x264_9.mp4
#   inflating: Dataset/explosion/Explosion013_x264_11.mp4
#   inflating: Dataset/explosion/Explosion013_x264_7.mp4
#   inflating: Dataset/explosion/Explosion009_x264_3.mp4
#   inflating: Dataset/explosion/Explosion017_x264_19.mp4
#   inflating: Dataset/explosion/Explosion013_x264_8.mp4
#   inflating: Dataset/explosion/Explosion017_x264_10.mp4
#   inflating: Dataset/explosion/Explosion009_x264_9.mp4
#   inflating: Dataset/explosion/Explosion009_x264_7.mp4
#   inflating: Dataset/explosion/Explosion011_x264_11.mp4
#   inflating: Dataset/explosion/Explosion009_x264_1.mp4
#   inflating: Dataset/explosion/Explosion013_x264_16.mp4
#   inflating: Dataset/explosion/Explosion011_x264_13.mp4
#   inflating: Dataset/explosion/Explosion017_x264_2.mp4
#   inflating: Dataset/explosion/Explosion009_x264_25.mp4
#   inflating: Dataset/explosion/Explosion014_x264_6.mp4
#   inflating: Dataset/explosion/Explosion011_x264_2.mp4
#   inflating: Dataset/explosion/Explosion020_x264_0.mp4
#   inflating: Dataset/explosion/Explosion013_x264_13.mp4
#   inflating: Dataset/explosion/Explosion017_x264_18.mp4
#   inflating: Dataset/explosion/Explosion009_x264_0.mp4
#   inflating: Dataset/explosion/Explosion009_x264_26.mp4
#   inflating: Dataset/explosion/Explosion011_x264_21.mp4
#   inflating: Dataset/explosion/Explosion014_x264_11.mp4
#   inflating: Dataset/explosion/Explosion009_x264_10.mp4
#   inflating: Dataset/explosion/Explosion011_x264_17.mp4
#   inflating: Dataset/explosion/Explosion014_x264_28.mp4
#   inflating: Dataset/explosion/Explosion009_x264_8.mp4
#   inflating: Dataset/explosion/Explosion011_x264_19.mp4
#   inflating: Dataset/explosion/Explosion020_x264_1.mp4
#   inflating: Dataset/explosion/Explosion014_x264_19.mp4
#   inflating: Dataset/explosion/Explosion009_x264_18.mp4
#   inflating: Dataset/explosion/Explosion017_x264_25.mp4
#   inflating: Dataset/explosion/Explosion006_x264_16.mp4
#   inflating: Dataset/explosion/Explosion004_x264_25.mp4
#   inflating: Dataset/explosion/Explosion017_x264_6.mp4
#   inflating: Dataset/explosion/Explosion009_x264_6.mp4
#   inflating: Dataset/explosion/Explosion006_x264_14.mp4
#   inflating: Dataset/explosion/Explosion013_x264_22.mp4
#   inflating: Dataset/explosion/Explosion014_x264_14.mp4
#   inflating: Dataset/explosion/Explosion008_x264_20.mp4
#   inflating: Dataset/explosion/Explosion013_x264_30.mp4
#   inflating: Dataset/explosion/Explosion011_x264_31.mp4
#   inflating: Dataset/explosion/Explosion017_x264_15.mp4
#   inflating: Dataset/explosion/Explosion014_x264_21.mp4
#   inflating: Dataset/explosion/Explosion008_x264_27.mp4
#   inflating: Dataset/explosion/Explosion006_x264_2.mp4
#   inflating: Dataset/explosion/Explosion013_x264_14.mp4
#   inflating: Dataset/explosion/Explosion008_x264_12.mp4
#   inflating: Dataset/explosion/Explosion004_x264_15.mp4
#   inflating: Dataset/explosion/Explosion004_x264_24.mp4
#   inflating: Dataset/explosion/Explosion004_x264_28.mp4
#   inflating: Dataset/explosion/Explosion013_x264_26.mp4
#   inflating: Dataset/explosion/Explosion008_x264_3.mp4
#   inflating: Dataset/explosion/Explosion009_x264_4.mp4
#   inflating: Dataset/explosion/Explosion011_x264_6.mp4
#   inflating: Dataset/explosion/Explosion008_x264_14.mp4
#   inflating: Dataset/explosion/Explosion008_x264_11.mp4
#   inflating: Dataset/explosion/Explosion006_x264_28.mp4
#   inflating: Dataset/explosion/Explosion006_x264_8.mp4
#   inflating: Dataset/explosion/Explosion004_x264_14.mp4
#   inflating: Dataset/explosion/Explosion008_x264_18.mp4
#   inflating: Dataset/explosion/Explosion004_x264_0.mp4
#   inflating: Dataset/explosion/Explosion008_x264_26.mp4
#   inflating: Dataset/explosion/Explosion009_x264_24.mp4
#   inflating: Dataset/explosion/Explosion004_x264_26.mp4
#   inflating: Dataset/explosion/Explosion004_x264_27.mp4
#   inflating: Dataset/explosion/Explosion014_x264_23.mp4
#   inflating: Dataset/explosion/Explosion004_x264_19.mp4
#   inflating: Dataset/explosion/Explosion006_x264_30.mp4
#   inflating: Dataset/explosion/Explosion004_x264_8.mp4
#   inflating: Dataset/explosion/Explosion006_x264_9.mp4
#   inflating: Dataset/explosion/Explosion006_x264_4.mp4
#   inflating: Dataset/explosion/Explosion004_x264_29.mp4
#   inflating: Dataset/explosion/Explosion004_x264_18.mp4
#   inflating: Dataset/explosion/Explosion004_x264_30.mp4
#   inflating: Dataset/explosion/Explosion006_x264_5.mp4
#   inflating: Dataset/explosion/Explosion004_x264_2.mp4
#   inflating: Dataset/explosion/Explosion006_x264_25.mp4
#   inflating: Dataset/explosion/Explosion008_x264_25.mp4
#   inflating: Dataset/explosion/Explosion006_x264_11.mp4
#   inflating: Dataset/explosion/Explosion006_x264_17.mp4
#   inflating: Dataset/explosion/Explosion008_x264_1.mp4
#   inflating: Dataset/explosion/Explosion008_x264_15.mp4
#   inflating: Dataset/explosion/Explosion004_x264_22.mp4
#   inflating: Dataset/explosion/Explosion004_x264_7.mp4
#   inflating: Dataset/explosion/Explosion004_x264_4.mp4
#   inflating: Dataset/explosion/Explosion008_x264_5.mp4
#   inflating: Dataset/explosion/Explosion004_x264_5.mp4
#   inflating: Dataset/explosion/Explosion004_x264_12.mp4
#   inflating: Dataset/explosion/Explosion008_x264_0.mp4
#   inflating: Dataset/burglary/Burglary014_x264_9.mp4
#   inflating: Dataset/explosion/Explosion008_x264_17.mp4
#   inflating: Dataset/explosion/Explosion008_x264_28.mp4
#   inflating: Dataset/burglary/Burglary015_x264_17.mp4
#   inflating: Dataset/explosion/Explosion006_x264_29.mp4
#   inflating: Dataset/explosion/Explosion008_x264_4.mp4
#   inflating: Dataset/burglary/Burglary015_x264_1.mp4
#   inflating: Dataset/explosion/Explosion017_x264_21.mp4
#   inflating: Dataset/explosion/Explosion006_x264_12.mp4
#   inflating: Dataset/explosion/Explosion004_x264_31.mp4
#   inflating: Dataset/burglary/Burglary015_x264_11.mp4
#   inflating: Dataset/burglary/Burglary015_x264_9.mp4
#   inflating: Dataset/explosion/Explosion006_x264_1.mp4
#   inflating: Dataset/explosion/Explosion006_x264_10.mp4
#   inflating: Dataset/burglary/Burglary015_x264_6.mp4
#   inflating: Dataset/burglary/Burglary015_x264_10.mp4
#   inflating: Dataset/burglary/Burglary014_x264_8.mp4
#   inflating: Dataset/burglary/Burglary015_x264_13.mp4
#   inflating: Dataset/explosion/Explosion004_x264_21.mp4
#   inflating: Dataset/explosion/Explosion008_x264_21.mp4
#   inflating: Dataset/burglary/Burglary014_x264_27.mp4
#   inflating: Dataset/explosion/Explosion006_x264_3.mp4
#   inflating: Dataset/burglary/Burglary015_x264_8.mp4
#   inflating: Dataset/burglary/Burglary014_x264_6.mp4
#   inflating: Dataset/burglary/Burglary015_x264_5.mp4
#   inflating: Dataset/explosion/Explosion004_x264_3.mp4
#   inflating: Dataset/explosion/Explosion006_x264_0.mp4
#   inflating: Dataset/explosion/Explosion004_x264_6.mp4
#   inflating: Dataset/explosion/Explosion006_x264_19.mp4
#   inflating: Dataset/burglary/Burglary014_x264_23.mp4
#   inflating: Dataset/burglary/Burglary014_x264_25.mp4
#   inflating: Dataset/explosion/Explosion004_x264_10.mp4
#   inflating: Dataset/explosion/Explosion006_x264_22.mp4
#   inflating: Dataset/explosion/Explosion006_x264_13.mp4
#   inflating: Dataset/burglary/Burglary014_x264_22.mp4
#   inflating: Dataset/burglary/Burglary015_x264_12.mp4
#   inflating: Dataset/explosion/Explosion004_x264_17.mp4
#   inflating: Dataset/explosion/Explosion006_x264_21.mp4
#   inflating: Dataset/explosion/Explosion006_x264_24.mp4
#   inflating: Dataset/explosion/Explosion006_x264_26.mp4
#   inflating: Dataset/burglary/Burglary015_x264_3.mp4
#   inflating: Dataset/burglary/Burglary015_x264_2.mp4
#   inflating: Dataset/burglary/Burglary014_x264_7.mp4
#   inflating: Dataset/explosion/Explosion004_x264_13.mp4
#   inflating: Dataset/explosion/Explosion008_x264_29.mp4
#   inflating: Dataset/burglary/Burglary015_x264_0.mp4
#   inflating: Dataset/explosion/Explosion008_x264_22.mp4
#   inflating: Dataset/explosion/Explosion006_x264_20.mp4
#   inflating: Dataset/explosion/Explosion008_x264_2.mp4
#   inflating: Dataset/explosion/Explosion004_x264_23.mp4
#   inflating: Dataset/burglary/Burglary014_x264_28.mp4
#   inflating: Dataset/explosion/Explosion006_x264_31.mp4
#   inflating: Dataset/explosion/Explosion004_x264_20.mp4
#   inflating: Dataset/explosion/Explosion004_x264_16.mp4
#   inflating: Dataset/burglary/Burglary014_x264_5.mp4
#   inflating: Dataset/burglary/Burglary015_x264_16.mp4
#   inflating: Dataset/burglary/Burglary014_x264_21.mp4
#   inflating: Dataset/explosion/Explosion008_x264_19.mp4
#   inflating: Dataset/explosion/Explosion008_x264_13.mp4
#   inflating: Dataset/burglary/Burglary014_x264_3.mp4
#   inflating: Dataset/burglary/Burglary014_x264_29.mp4
#   inflating: Dataset/burglary/Burglary014_x264_31.mp4
#   inflating: Dataset/explosion/Explosion004_x264_11.mp4
#   inflating: Dataset/burglary/Burglary015_x264_4.mp4
#   inflating: Dataset/burglary/Burglary007_x264_6.mp4
#   inflating: Dataset/burglary/Burglary014_x264_4.mp4
#   inflating: Dataset/burglary/Burglary009_x264_23.mp4
#   inflating: Dataset/burglary/Burglary012_x264_20.mp4
#   inflating: Dataset/burglary/Burglary012_x264_7.mp4
#   inflating: Dataset/burglary/Burglary013_x264_19.mp4
#   inflating: Dataset/burglary/Burglary014_x264_24.mp4
#   inflating: Dataset/burglary/Burglary015_x264_14.mp4
#   inflating: Dataset/burglary/Burglary012_x264_31.mp4
#   inflating: Dataset/explosion/Explosion006_x264_23.mp4
#   inflating: Dataset/burglary/Burglary009_x264_20.mp4
#   inflating: Dataset/burglary/Burglary009_x264_21.mp4
#   inflating: Dataset/burglary/Burglary004_x264_16.mp4
#   inflating: Dataset/burglary/Burglary004_x264_12.mp4
#   inflating: Dataset/burglary/Burglary013_x264_30.mp4
#   inflating: Dataset/burglary/Burglary014_x264_30.mp4
#   inflating: Dataset/burglary/Burglary001_x264_15.mp4
#   inflating: Dataset/explosion/Explosion008_x264_16.mp4
#   inflating: Dataset/burglary/Burglary004_x264_11.mp4
#   inflating: Dataset/burglary/Burglary001_x264_12.mp4
#   inflating: Dataset/burglary/Burglary014_x264_26.mp4
#   inflating: Dataset/burglary/Burglary001_x264_19.mp4
#   inflating: Dataset/burglary/Burglary013_x264_16.mp4
#   inflating: Dataset/burglary/Burglary004_x264_21.mp4
#   inflating: Dataset/burglary/Burglary015_x264_7.mp4
#   inflating: Dataset/burglary/Burglary001_x264_3.mp4
#   inflating: Dataset/burglary/Burglary015_x264_15.mp4
#   inflating: Dataset/burglary/Burglary012_x264_2.mp4
#   inflating: Dataset/burglary/Burglary001_x264_6.mp4
#   inflating: Dataset/burglary/Burglary013_x264_24.mp4
#   inflating: Dataset/burglary/Burglary012_x264_23.mp4
#   inflating: Dataset/burglary/Burglary013_x264_1.mp4
#   inflating: Dataset/burglary/Burglary012_x264_3.mp4
#   inflating: Dataset/burglary/Burglary014_x264_10.mp4
#   inflating: Dataset/burglary/Burglary013_x264_12.mp4
#   inflating: Dataset/burglary/Burglary004_x264_3.mp4
#   inflating: Dataset/burglary/Burglary001_x264_24.mp4
#   inflating: Dataset/burglary/Burglary013_x264_2.mp4
#   inflating: Dataset/burglary/Burglary014_x264_20.mp4
#   inflating: Dataset/burglary/Burglary011_x264_6.mp4
#   inflating: Dataset/burglary/Burglary012_x264_9.mp4
#   inflating: Dataset/burglary/Burglary011_x264_16.mp4
#   inflating: Dataset/burglary/Burglary011_x264_14.mp4
#   inflating: Dataset/burglary/Burglary014_x264_19.mp4
#   inflating: Dataset/burglary/Burglary011_x264_26.mp4
#   inflating: Dataset/burglary/Burglary012_x264_12.mp4
#   inflating: Dataset/burglary/Burglary001_x264_28.mp4
#   inflating: Dataset/burglary/Burglary007_x264_21.mp4
#   inflating: Dataset/burglary/Burglary007_x264_9.mp4
#   inflating: Dataset/burglary/Burglary014_x264_14.mp4
#   inflating: Dataset/burglary/Burglary011_x264_13.mp4
#   inflating: Dataset/burglary/Burglary004_x264_18.mp4
#   inflating: Dataset/burglary/Burglary012_x264_25.mp4
#   inflating: Dataset/burglary/Burglary009_x264_15.mp4
#   inflating: Dataset/burglary/Burglary004_x264_14.mp4
#   inflating: Dataset/burglary/Burglary014_x264_13.mp4
#   inflating: Dataset/burglary/Burglary013_x264_29.mp4
#   inflating: Dataset/burglary/Burglary004_x264_26.mp4
#   inflating: Dataset/burglary/Burglary007_x264_12.mp4
#   inflating: Dataset/burglary/Burglary007_x264_20.mp4
#   inflating: Dataset/burglary/Burglary012_x264_14.mp4
#   inflating: Dataset/burglary/Burglary001_x264_13.mp4
#   inflating: Dataset/burglary/Burglary001_x264_16.mp4
#   inflating: Dataset/burglary/Burglary009_x264_12.mp4
#   inflating: Dataset/burglary/Burglary001_x264_11.mp4
#   inflating: Dataset/burglary/Burglary013_x264_23.mp4
#   inflating: Dataset/burglary/Burglary011_x264_1.mp4
#   inflating: Dataset/burglary/Burglary011_x264_31.mp4
#   inflating: Dataset/burglary/Burglary013_x264_6.mp4
#   inflating: Dataset/burglary/Burglary007_x264_23.mp4
#   inflating: Dataset/burglary/Burglary004_x264_9.mp4
#   inflating: Dataset/burglary/Burglary013_x264_28.mp4
#   inflating: Dataset/burglary/Burglary007_x264_2.mp4
#   inflating: Dataset/burglary/Burglary001_x264_25.mp4
#   inflating: Dataset/burglary/Burglary004_x264_0.mp4
#   inflating: Dataset/burglary/Burglary009_x264_9.mp4
#   inflating: Dataset/burglary/Burglary004_x264_24.mp4
#   inflating: Dataset/burglary/Burglary007_x264_31.mp4
#   inflating: Dataset/burglary/Burglary013_x264_22.mp4
#   inflating: Dataset/burglary/Burglary009_x264_18.mp4
#   inflating: Dataset/burglary/Burglary009_x264_17.mp4
#   inflating: Dataset/burglary/Burglary001_x264_27.mp4
#   inflating: Dataset/burglary/Burglary009_x264_26.mp4
#   inflating: Dataset/burglary/Burglary012_x264_21.mp4
#   inflating: Dataset/burglary/Burglary013_x264_9.mp4
#   inflating: Dataset/explosion/Explosion008_x264_30.mp4
#   inflating: Dataset/burglary/Burglary004_x264_29.mp4
#   inflating: Dataset/burglary/Burglary012_x264_6.mp4
#   inflating: Dataset/burglary/Burglary007_x264_5.mp4
#   inflating: Dataset/burglary/Burglary013_x264_20.mp4
#   inflating: Dataset/burglary/Burglary009_x264_25.mp4
#   inflating: Dataset/burglary/Burglary004_x264_5.mp4
#   inflating: Dataset/burglary/Burglary001_x264_8.mp4
#   inflating: Dataset/burglary/Burglary011_x264_22.mp4
#   inflating: Dataset/burglary/Burglary007_x264_25.mp4
#   inflating: Dataset/burglary/Burglary012_x264_15.mp4
#   inflating: Dataset/burglary/Burglary004_x264_4.mp4
#   inflating: Dataset/burglary/Burglary007_x264_8.mp4
#   inflating: Dataset/burglary/Burglary013_x264_13.mp4
#   inflating: Dataset/burglary/Burglary007_x264_30.mp4
#   inflating: Dataset/burglary/Burglary013_x264_10.mp4
#   inflating: Dataset/burglary/Burglary011_x264_15.mp4
#   inflating: Dataset/burglary/Burglary004_x264_19.mp4
#   inflating: Dataset/burglary/Burglary011_x264_10.mp4
#   inflating: Dataset/burglary/Burglary001_x264_22.mp4
#   inflating: Dataset/burglary/Burglary014_x264_16.mp4
#   inflating: Dataset/burglary/Burglary009_x264_28.mp4
#   inflating: Dataset/burglary/Burglary001_x264_30.mp4
#   inflating: Dataset/burglary/Burglary011_x264_0.mp4
#   inflating: Dataset/burglary/Burglary009_x264_29.mp4
#   inflating: Dataset/burglary/Burglary013_x264_31.mp4
#   inflating: Dataset/burglary/Burglary007_x264_26.mp4
#   inflating: Dataset/burglary/Burglary009_x264_27.mp4
#   inflating: Dataset/burglary/Burglary014_x264_2.mp4
#   inflating: Dataset/burglary/Burglary009_x264_6.mp4
#   inflating: Dataset/burglary/Burglary007_x264_17.mp4
#   inflating: Dataset/burglary/Burglary004_x264_28.mp4
#   inflating: Dataset/burglary/Burglary007_x264_1.mp4
#   inflating: Dataset/burglary/Burglary012_x264_28.mp4
#   inflating: Dataset/burglary/Burglary004_x264_15.mp4
#   inflating: Dataset/burglary/Burglary012_x264_22.mp4
#   inflating: Dataset/burglary/Burglary009_x264_4.mp4
#   inflating: Dataset/burglary/Burglary013_x264_25.mp4
#   inflating: Dataset/burglary/Burglary012_x264_26.mp4
#   inflating: Dataset/burglary/Burglary009_x264_10.mp4
#   inflating: Dataset/burglary/Burglary011_x264_27.mp4
#   inflating: Dataset/burglary/Burglary001_x264_14.mp4
#   inflating: Dataset/burglary/Burglary001_x264_26.mp4
#   inflating: Dataset/burglary/Burglary013_x264_18.mp4
#   inflating: Dataset/burglary/Burglary013_x264_5.mp4
#   inflating: Dataset/burglary/Burglary004_x264_6.mp4
#   inflating: Dataset/burglary/Burglary011_x264_9.mp4
#   inflating: Dataset/burglary/Burglary004_x264_20.mp4
#   inflating: Dataset/burglary/Burglary013_x264_7.mp4
#   inflating: Dataset/burglary/Burglary013_x264_0.mp4
#   inflating: Dataset/burglary/Burglary011_x264_11.mp4
#   inflating: Dataset/burglary/Burglary007_x264_7.mp4
#   inflating: Dataset/burglary/Burglary007_x264_24.mp4
#   inflating: Dataset/burglary/Burglary013_x264_8.mp4
#   inflating: Dataset/burglary/Burglary009_x264_3.mp4
#   inflating: Dataset/burglary/Burglary004_x264_27.mp4
#   inflating: Dataset/burglary/Burglary007_x264_13.mp4
#   inflating: Dataset/burglary/Burglary004_x264_2.mp4
#   inflating: Dataset/burglary/Burglary001_x264_17.mp4
#   inflating: Dataset/burglary/Burglary009_x264_7.mp4
#   inflating: Dataset/burglary/Burglary007_x264_27.mp4
#   inflating: Dataset/burglary/Burglary004_x264_8.mp4
#   inflating: Dataset/burglary/Burglary004_x264_30.mp4
#   inflating: Dataset/burglary/Burglary013_x264_15.mp4
#   inflating: Dataset/burglary/Burglary004_x264_22.mp4
#   inflating: Dataset/burglary/Burglary001_x264_2.mp4
#   inflating: Dataset/burglary/Burglary012_x264_30.mp4
#   inflating: Dataset/burglary/Burglary009_x264_2.mp4
#   inflating: Dataset/burglary/Burglary007_x264_3.mp4
#   inflating: Dataset/burglary/Burglary011_x264_28.mp4
#   inflating: Dataset/burglary/Burglary011_x264_3.mp4
#   inflating: Dataset/burglary/Burglary014_x264_0.mp4
#   inflating: Dataset/burglary/Burglary012_x264_17.mp4
#   inflating: Dataset/burglary/Burglary009_x264_1.mp4
#   inflating: Dataset/burglary/Burglary013_x264_27.mp4
#   inflating: Dataset/burglary/Burglary007_x264_11.mp4
#   inflating: Dataset/burglary/Burglary011_x264_30.mp4
#   inflating: Dataset/burglary/Burglary013_x264_4.mp4
#   inflating: Dataset/burglary/Burglary007_x264_18.mp4
#   inflating: Dataset/burglary/Burglary009_x264_14.mp4
#   inflating: Dataset/burglary/Burglary011_x264_17.mp4
#   inflating: Dataset/burglary/Burglary012_x264_4.mp4
#   inflating: Dataset/burglary/Burglary014_x264_11.mp4
#   inflating: Dataset/burglary/Burglary012_x264_5.mp4
#   inflating: Dataset/burglary/Burglary009_x264_5.mp4
#   inflating: Dataset/burglary/Burglary012_x264_13.mp4
#   inflating: Dataset/burglary/Burglary011_x264_8.mp4
#   inflating: Dataset/burglary/Burglary012_x264_11.mp4
#   inflating: Dataset/burglary/Burglary004_x264_23.mp4
#   inflating: Dataset/burglary/Burglary009_x264_19.mp4
#   inflating: Dataset/burglary/Burglary001_x264_29.mp4
#   inflating: Dataset/burglary/Burglary004_x264_25.mp4
#   inflating: Dataset/burglary/Burglary009_x264_24.mp4
#   inflating: Dataset/burglary/Burglary004_x264_13.mp4
#   inflating: Dataset/burglary/Burglary007_x264_16.mp4
#   inflating: Dataset/burglary/Burglary004_x264_31.mp4
#   inflating: Dataset/burglary/Burglary001_x264_4.mp4
#   inflating: Dataset/burglary/Burglary011_x264_4.mp4
#   inflating: Dataset/burglary/Burglary011_x264_29.mp4
#   inflating: Dataset/burglary/Burglary009_x264_0.mp4
#   inflating: Dataset/burglary/Burglary011_x264_12.mp4
#   inflating: Dataset/burglary/Burglary011_x264_24.mp4
#   inflating: Dataset/burglary/Burglary001_x264_10.mp4
#   inflating: Dataset/burglary/Burglary012_x264_16.mp4
#   inflating: Dataset/burglary/Burglary012_x264_1.mp4
#   inflating: Dataset/shooting/Shooting008_x264_1.mp4
#   inflating: Dataset/shooting/Shooting008_x264_28.mp4
#   inflating: Dataset/burglary/Burglary009_x264_22.mp4
#   inflating: Dataset/shooting/Shooting010_x264_21.mp4
#   inflating: Dataset/shooting/Shooting002_x264_22.mp4
#   inflating: Dataset/burglary/Burglary012_x264_18.mp4
#   inflating: Dataset/burglary/Burglary011_x264_18.mp4
#   inflating: Dataset/burglary/Burglary011_x264_5.mp4
#   inflating: Dataset/shooting/Shooting007_x264_15.mp4
#   inflating: Dataset/burglary/Burglary009_x264_16.mp4
#   inflating: Dataset/burglary/Burglary007_x264_0.mp4
#   inflating: Dataset/burglary/Burglary004_x264_7.mp4
#   inflating: Dataset/shooting/Shooting002_x264_6.mp4
#   inflating: Dataset/burglary/Burglary011_x264_19.mp4
#   inflating: Dataset/shooting/Shooting010_x264_2.mp4
#   inflating: Dataset/shooting/Shooting009_x264_8.mp4
#   inflating: Dataset/burglary/Burglary001_x264_5.mp4
#   inflating: Dataset/shooting/Shooting008_x264_3.mp4
#   inflating: Dataset/burglary/Burglary001_x264_9.mp4
#   inflating: Dataset/burglary/Burglary007_x264_29.mp4
#   inflating: Dataset/burglary/Burglary011_x264_20.mp4
#   inflating: Dataset/shooting/Shooting005_x264_24.mp4
#   inflating: Dataset/shooting/Shooting008_x264_23.mp4
#   inflating: Dataset/burglary/Burglary014_x264_18.mp4
#   inflating: Dataset/burglary/Burglary001_x264_23.mp4
#   inflating: Dataset/shooting/Shooting009_x264_19.mp4
#   inflating: Dataset/burglary/Burglary012_x264_10.mp4
#   inflating: Dataset/burglary/Burglary009_x264_11.mp4
#   inflating: Dataset/shooting/Shooting008_x264_29.mp4
#   inflating: Dataset/shooting/Shooting009_x264_18.mp4
#   inflating: Dataset/burglary/Burglary014_x264_17.mp4
#   inflating: Dataset/burglary/Burglary013_x264_21.mp4
#   inflating: Dataset/burglary/Burglary013_x264_11.mp4
#   inflating: Dataset/shooting/Shooting009_x264_9.mp4
#   inflating: Dataset/burglary/Burglary001_x264_31.mp4
#   inflating: Dataset/burglary/Burglary007_x264_15.mp4
#   inflating: Dataset/shooting/Shooting009_x264_30.mp4
#   inflating: Dataset/burglary/Burglary014_x264_12.mp4
#   inflating: Dataset/burglary/Burglary014_x264_1.mp4
#   inflating: Dataset/shooting/Shooting005_x264_18.mp4
#   inflating: Dataset/shooting/Shooting005_x264_5.mp4
#   inflating: Dataset/shooting/Shooting009_x264_4.mp4
#   inflating: Dataset/burglary/Burglary012_x264_27.mp4
#   inflating: Dataset/burglary/Burglary014_x264_15.mp4
#   inflating: Dataset/shooting/Shooting007_x264_16.mp4
#   inflating: Dataset/burglary/Burglary001_x264_7.mp4
#   inflating: Dataset/burglary/Burglary011_x264_21.mp4
#   inflating: Dataset/shooting/Shooting010_x264_16.mp4
#   inflating: Dataset/shooting/Shooting002_x264_29.mp4
#   inflating: Dataset/shooting/Shooting009_x264_15.mp4
#   inflating: Dataset/burglary/Burglary011_x264_2.mp4
#   inflating: Dataset/burglary/Burglary009_x264_8.mp4
#   inflating: Dataset/shooting/Shooting002_x264_1.mp4
#   inflating: Dataset/shooting/Shooting005_x264_17.mp4
#   inflating: Dataset/shooting/Shooting005_x264_12.mp4
#   inflating: Dataset/burglary/Burglary001_x264_20.mp4
#   inflating: Dataset/burglary/Burglary012_x264_0.mp4
#   inflating: Dataset/shooting/Shooting005_x264_6.mp4
#   inflating: Dataset/shooting/Shooting007_x264_8.mp4
#   inflating: Dataset/shooting/Shooting008_x264_24.mp4
#   inflating: Dataset/burglary/Burglary012_x264_24.mp4
#   inflating: Dataset/burglary/Burglary013_x264_14.mp4
#   inflating: Dataset/shooting/Shooting005_x264_0.mp4
#   inflating: Dataset/shooting/Shooting010_x264_20.mp4
#   inflating: Dataset/burglary/Burglary012_x264_29.mp4
#   inflating: Dataset/shooting/Shooting008_x264_2.mp4
#   inflating: Dataset/shooting/Shooting008_x264_30.mp4
#   inflating: Dataset/shooting/Shooting008_x264_26.mp4
#   inflating: Dataset/shooting/Shooting009_x264_12.mp4
#   inflating: Dataset/burglary/Burglary012_x264_8.mp4
#   inflating: Dataset/burglary/Burglary013_x264_26.mp4
#   inflating: Dataset/shooting/Shooting007_x264_14.mp4
#   inflating: Dataset/burglary/Burglary004_x264_1.mp4
#   inflating: Dataset/burglary/Burglary007_x264_22.mp4
#   inflating: Dataset/burglary/Burglary001_x264_18.mp4
#   inflating: Dataset/burglary/Burglary007_x264_19.mp4
#   inflating: Dataset/explosion/Explosion008_x264_24.mp4
#   inflating: Dataset/burglary/Burglary011_x264_25.mp4
#   inflating: Dataset/burglary/Burglary009_x264_13.mp4
#   inflating: Dataset/burglary/Burglary009_x264_30.mp4
#   inflating: Dataset/burglary/Burglary009_x264_31.mp4
#   inflating: Dataset/explosion/Explosion006_x264_7.mp4
#   inflating: Dataset/burglary/Burglary007_x264_14.mp4
#   inflating: Dataset/burglary/Burglary012_x264_19.mp4
#   inflating: Dataset/burglary/Burglary013_x264_3.mp4
#   inflating: Dataset/burglary/Burglary013_x264_17.mp4
#   inflating: Dataset/explosion/Explosion006_x264_27.mp4
#   inflating: Dataset/burglary/Burglary001_x264_21.mp4
#   inflating: Dataset/burglary/Burglary007_x264_4.mp4
#   inflating: Dataset/explosion/Explosion004_x264_1.mp4
#   inflating: Dataset/shooting/Shooting008_x264_19.mp4
#   inflating: Dataset/explosion/Explosion008_x264_23.mp4
#   inflating: Dataset/explosion/Explosion006_x264_6.mp4
#   inflating: Dataset/burglary/Burglary007_x264_28.mp4
#   inflating: Dataset/shooting/Shooting005_x264_20.mp4
#   inflating: Dataset/explosion/Explosion004_x264_9.mp4
#   inflating: Dataset/burglary/Burglary004_x264_10.mp4
#   inflating: Dataset/burglary/Burglary004_x264_17.mp4
#   inflating: Dataset/burglary/Burglary007_x264_10.mp4
#   inflating: Dataset/explosion/Explosion008_x264_10.mp4
#   inflating: Dataset/burglary/Burglary011_x264_7.mp4
#   inflating: Dataset/explosion/Explosion006_x264_15.mp4
#   inflating: Dataset/shooting/Shooting007_x264_7.mp4
#   inflating: Dataset/explosion/Explosion006_x264_18.mp4
#   inflating: Dataset/shooting/Shooting009_x264_13.mp4
#   inflating: Dataset/burglary/Burglary011_x264_23.mp4
#   inflating: Dataset/shooting/Shooting010_x264_14.mp4
#   inflating: Dataset/explosion/Explosion008_x264_31.mp4

# %%
# !unzip Dataset.zip
# Out:
# Archive:  Dataset.zip
#    creating: Dataset/
#    creating: Dataset/walking/
#   inflating: Dataset/walking/person01_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person01_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person01_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person01_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person02_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person02_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person02_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person02_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person03_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person03_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person03_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person03_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person04_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person04_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person04_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person04_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person05_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person05_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person05_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person05_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person06_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person06_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person06_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person06_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person07_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person07_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person07_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person07_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person08_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person08_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person08_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person08_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person09_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person09_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person09_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person09_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person10_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person10_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person10_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person10_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person11_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person11_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person11_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person11_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person12_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person12_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person12_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person12_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person13_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person13_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person13_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person13_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person14_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person14_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person14_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person14_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person15_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person15_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person15_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person15_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person16_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person16_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person16_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person16_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person17_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person17_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person17_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person17_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person18_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person18_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person18_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person18_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person19_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person19_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person19_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person19_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person20_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person20_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person20_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person20_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person21_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person21_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person21_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person21_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person22_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person22_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person22_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person22_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person23_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person23_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person23_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person23_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person24_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person24_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person24_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person24_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person25_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person25_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person25_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person25_walking_d4_uncomp.avi
#    creating: Dataset/fights/
#   inflating: Dataset/fights/newfi1.avi
#   inflating: Dataset/fights/newfi10.avi
#   inflating: Dataset/fights/newfi100.avi
#   inflating: Dataset/fights/newfi11.avi
#   inflating: Dataset/fights/newfi12.avi
#   inflating: Dataset/fights/newfi13.avi
#   inflating: Dataset/fights/newfi14.avi
#   inflating: Dataset/fights/newfi15.avi
#   inflating: Dataset/fights/newfi16.avi
#   inflating: Dataset/fights/newfi17.avi
#   inflating: Dataset/fights/newfi18.avi
#   inflating: Dataset/fights/newfi19.avi
#   inflating: Dataset/fights/newfi2.avi
#   inflating: Dataset/fights/newfi20.avi
#   inflating: Dataset/fights/newfi21.avi
#   inflating: Dataset/fights/newfi22.avi
#   inflating: Dataset/fights/newfi23.avi
#   inflating: Dataset/fights/newfi24.avi
#   inflating: Dataset/fights/newfi25.avi
#   inflating: Dataset/fights/newfi26.avi
#   inflating: Dataset/fights/newfi27.avi
#   inflating: Dataset/fights/newfi28.avi
#   inflating: Dataset/fights/newfi29.avi
#   inflating: Dataset/fights/newfi3.avi
#   inflating: Dataset/fights/newfi30.avi
#   inflating: Dataset/fights/newfi31.avi
#   inflating: Dataset/fights/newfi32.avi
#   inflating: Dataset/fights/newfi33.avi
#   inflating: Dataset/fights/newfi34.avi
#   inflating: Dataset/fights/newfi35.avi
#   inflating: Dataset/fights/newfi36.avi
#   inflating: Dataset/fights/newfi37.avi
#   inflating: Dataset/fights/newfi38.avi
#   inflating: Dataset/fights/newfi39.avi
#   inflating: Dataset/fights/newfi4.avi
#   inflating: Dataset/fights/newfi40.avi
#   inflating: Dataset/fights/newfi41.avi
#   inflating: Dataset/fights/newfi42.avi
#   inflating: Dataset/fights/newfi43.avi
#   inflating: Dataset/fights/newfi44.avi
#   inflating: Dataset/fights/newfi45.avi
#   inflating: Dataset/fights/newfi46.avi
#   inflating: Dataset/fights/newfi47.avi
#   inflating: Dataset/fights/newfi48.avi
#   inflating: Dataset/fights/newfi49.avi
#   inflating: Dataset/fights/newfi5.avi
#   inflating: Dataset/fights/newfi50.avi
#   inflating: Dataset/fights/newfi51.avi
#   inflating: Dataset/fights/newfi52.avi
#   inflating: Dataset/fights/newfi53.avi
#   inflating: Dataset/fights/newfi54.avi
#   inflating: Dataset/fights/newfi55.avi
#   inflating: Dataset/fights/newfi56.avi
#   inflating: Dataset/fights/newfi57.avi
#   inflating: Dataset/fights/newfi58.avi
#   inflating: Dataset/fights/newfi59.avi
#   inflating: Dataset/fights/newfi6.avi
#   inflating: Dataset/fights/newfi60.avi
#   inflating: Dataset/fights/newfi61.avi
#   inflating: Dataset/fights/newfi62.avi
#   inflating: Dataset/fights/newfi63.avi
#   inflating: Dataset/fights/newfi64.avi
#   inflating: Dataset/fights/newfi65.avi
#   inflating: Dataset/fights/newfi66.avi
#   inflating: Dataset/fights/newfi67.avi
#   inflating: Dataset/fights/newfi68.avi
#   inflating: Dataset/fights/newfi69.avi
#   inflating: Dataset/fights/newfi7.avi
#   inflating: Dataset/fights/newfi70.avi
#   inflating: Dataset/fights/newfi71.avi
#   inflating: Dataset/fights/newfi72.avi
#   inflating: Dataset/fights/newfi73.avi
#   inflating: Dataset/fights/newfi74avi.avi
#   inflating: Dataset/fights/newfi75.avi
#   inflating: Dataset/fights/newfi76.avi
#   inflating: Dataset/fights/newfi77.avi
#   inflating: Dataset/fights/newfi78.avi
#   inflating: Dataset/fights/newfi79.avi
#   inflating: Dataset/fights/newfi8.avi
#   inflating: Dataset/fights/newfi80.avi
#   inflating: Dataset/fights/newfi81.avi
#   inflating: Dataset/fights/newfi82.avi
#   inflating: Dataset/fights/newfi83.avi
#   inflating: Dataset/fights/newfi84.avi
#   inflating: Dataset/fights/newfi85.avi
#   inflating: Dataset/fights/newfi86.avi
#   inflating: Dataset/fights/newfi87.avi
#   inflating: Dataset/fights/newfi88.avi
#   inflating: Dataset/fights/newfi89.avi
#   inflating: Dataset/fights/newfi9.avi
#   inflating: Dataset/fights/newfi90.avi
#   inflating: Dataset/fights/newfi91.avi
#   inflating: Dataset/fights/newfi92.avi
#   inflating: Dataset/fights/newfi93.avi
#   inflating: Dataset/fights/newfi94.avi
#   inflating: Dataset/fights/newfi95.avi
#   inflating: Dataset/fights/newfi96.avi
#   inflating: Dataset/fights/newfi97.avi
#   inflating: Dataset/fights/newfi98.avi
#   inflating: Dataset/fights/newfi99.avi
#    creating: Dataset/running/
#   inflating: Dataset/running/person01_running_d1_uncomp.avi
#   inflating: Dataset/running/person01_running_d2_uncomp.avi
#   inflating: Dataset/running/person01_running_d3_uncomp.avi
#   inflating: Dataset/running/person01_running_d4_uncomp.avi
#   inflating: Dataset/running/person02_running_d1_uncomp.avi
#   inflating: Dataset/running/person02_running_d2_uncomp.avi
#   inflating: Dataset/running/person02_running_d3_uncomp.avi
#   inflating: Dataset/running/person02_running_d4_uncomp.avi
#   inflating: Dataset/running/person03_running_d1_uncomp.avi
#   inflating: Dataset/running/person03_running_d2_uncomp.avi
#   inflating: Dataset/running/person03_running_d3_uncomp.avi
#   inflating: Dataset/running/person03_running_d4_uncomp.avi
#   inflating: Dataset/running/person04_running_d1_uncomp.avi
#   inflating: Dataset/running/person04_running_d2_uncomp.avi
#   inflating: Dataset/running/person04_running_d3_uncomp.avi
#   inflating: Dataset/running/person04_running_d4_uncomp.avi
#   inflating: Dataset/running/person05_running_d1_uncomp.avi
#   inflating: Dataset/running/person05_running_d2_uncomp.avi
#   inflating: Dataset/running/person05_running_d3_uncomp.avi
#   inflating: Dataset/running/person05_running_d4_uncomp.avi
#   inflating: Dataset/running/person06_running_d1_uncomp.avi
#   inflating: Dataset/running/person06_running_d2_uncomp.avi
#   inflating: Dataset/running/person06_running_d3_uncomp.avi
#   inflating: Dataset/running/person06_running_d4_uncomp.avi
#   inflating: Dataset/running/person07_running_d1_uncomp.avi
#   inflating: Dataset/running/person07_running_d2_uncomp.avi
#   inflating: Dataset/running/person07_running_d3_uncomp.avi
#   inflating: Dataset/running/person07_running_d4_uncomp.avi
#   inflating: Dataset/running/person08_running_d1_uncomp.avi
#   inflating: Dataset/running/person08_running_d2_uncomp.avi
#   inflating: Dataset/running/person08_running_d3_uncomp.avi
#   inflating: Dataset/running/person08_running_d4_uncomp.avi
#   inflating: Dataset/running/person09_running_d1_uncomp.avi
#   inflating: Dataset/running/person09_running_d2_uncomp.avi
#   inflating: Dataset/running/person09_running_d3_uncomp.avi
#   inflating: Dataset/running/person09_running_d4_uncomp.avi
#   inflating: Dataset/running/person10_running_d1_uncomp.avi
#   inflating: Dataset/running/person10_running_d2_uncomp.avi
#   inflating: Dataset/running/person10_running_d3_uncomp.avi
#   inflating: Dataset/running/person10_running_d4_uncomp.avi
#   inflating: Dataset/running/person11_running_d1_uncomp.avi
#   inflating: Dataset/running/person11_running_d2_uncomp.avi
#   inflating: Dataset/running/person11_running_d3_uncomp.avi
#   inflating: Dataset/running/person11_running_d4_uncomp.avi
#   inflating: Dataset/running/person12_running_d1_uncomp.avi
#   inflating: Dataset/running/person12_running_d2_uncomp.avi
#   inflating: Dataset/running/person12_running_d3_uncomp.avi
#   inflating: Dataset/running/person12_running_d4_uncomp.avi
#   inflating: Dataset/running/person13_running_d1_uncomp.avi
#   inflating: Dataset/running/person13_running_d2_uncomp.avi
#   inflating: Dataset/running/person13_running_d3_uncomp.avi
#   inflating: Dataset/running/person13_running_d4_uncomp.avi
#   inflating: Dataset/running/person14_running_d1_uncomp.avi
#   inflating: Dataset/running/person14_running_d2_uncomp.avi
#   inflating: Dataset/running/person14_running_d3_uncomp.avi
#   inflating: Dataset/running/person14_running_d4_uncomp.avi
#   inflating: Dataset/running/person15_running_d1_uncomp.avi
#   inflating: Dataset/running/person15_running_d2_uncomp.avi
#   inflating: Dataset/running/person15_running_d3_uncomp.avi
#   inflating: Dataset/running/person15_running_d4_uncomp.avi
#   inflating: Dataset/running/person16_running_d1_uncomp.avi
#   inflating: Dataset/running/person16_running_d2_uncomp.avi
#   inflating: Dataset/running/person16_running_d3_uncomp.avi
#   inflating: Dataset/running/person16_running_d4_uncomp.avi
#   inflating: Dataset/running/person17_running_d1_uncomp.avi
#   inflating: Dataset/running/person17_running_d2_uncomp.avi
#   inflating: Dataset/running/person17_running_d3_uncomp.avi
#   inflating: Dataset/running/person17_running_d4_uncomp.avi
#   inflating: Dataset/running/person18_running_d1_uncomp.avi
#   inflating: Dataset/running/person18_running_d2_uncomp.avi
#   inflating: Dataset/running/person18_running_d3_uncomp.avi
#   inflating: Dataset/running/person18_running_d4_uncomp.avi
#   inflating: Dataset/running/person19_running_d1_uncomp.avi
#   inflating: Dataset/running/person19_running_d2_uncomp.avi
#   inflating: Dataset/running/person19_running_d3_uncomp.avi
#   inflating: Dataset/running/person19_running_d4_uncomp.avi
#   inflating: Dataset/running/person20_running_d1_uncomp.avi
#   inflating: Dataset/running/person20_running_d2_uncomp.avi
#   inflating: Dataset/running/person20_running_d3_uncomp.avi
#   inflating: Dataset/running/person20_running_d4_uncomp.avi
#   inflating: Dataset/running/person21_running_d1_uncomp.avi
#   inflating: Dataset/running/person21_running_d2_uncomp.avi
#   inflating: Dataset/running/person21_running_d3_uncomp.avi
#   inflating: Dataset/running/person21_running_d4_uncomp.avi
#   inflating: Dataset/running/person22_running_d1_uncomp.avi
#   inflating: Dataset/running/person22_running_d2_uncomp.avi
#   inflating: Dataset/running/person22_running_d3_uncomp.avi
#   inflating: Dataset/running/person22_running_d4_uncomp.avi
#   inflating: Dataset/running/person23_running_d1_uncomp.avi
#   inflating: Dataset/running/person23_running_d2_uncomp.avi
#   inflating: Dataset/running/person23_running_d3_uncomp.avi
#   inflating: Dataset/running/person23_running_d4_uncomp.avi
#   inflating: Dataset/running/person24_running_d1_uncomp.avi
#   inflating: Dataset/running/person24_running_d2_uncomp.avi
#   inflating: Dataset/running/person24_running_d3_uncomp.avi
#   inflating: Dataset/running/person24_running_d4_uncomp.avi
#   inflating: Dataset/running/person25_running_d1_uncomp.avi
#   inflating: Dataset/running/person25_running_d2_uncomp.avi
#   inflating: Dataset/running/person25_running_d3_uncomp.avi
#   inflating: Dataset/running/person25_running_d4_uncomp.avi

# %% [markdown]
# # Import Required Libraries

# %%
# !pip install pafy youtube-dl moviepy
# Out:
# Collecting pafy
#   Downloading pafy-0.5.5-py2.py3-none-any.whl.metadata (10 kB)
# Collecting youtube-dl
#   Downloading youtube_dl-2021.12.17-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.11/dist-packages (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.11/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.11/dist-packages (from moviepy) (4.67.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from moviepy) (2.32.3)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.11/dist-packages (from moviepy) (0.1.12)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.11/dist-packages (from moviepy) (2.0.2)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.11/dist-packages (from moviepy) (2.37.0)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from moviepy) (0.6.0)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.11/dist-packages (from imageio<3.0,>=2.5->moviepy) (11.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2025.4.26)
# Downloading pafy-0.5.5-py2.py3-none-any.whl (35 kB)
# Downloading youtube_dl-2021.12.17-py2.py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 49.3 MB/s eta 0:00:00
# Installing collected packages: youtube-dl, pafy
# Successfully installed pafy-0.5.5 youtube-dl-2021.12.17

# %%
import os
import cv2
import pafy
import math
import random
import numpy as np
import datetime as dt
import tensorflow as tf
from collections import deque
import matplotlib.pyplot as plt

from moviepy.editor import *
# %matplotlib inline

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/moviepy/video/io/sliders.py:61: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if event.key is 'enter':

# %% [markdown]
# # Select Randomness

# %%
seed_constant = 5
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

# %% [markdown]
# # View the dataset

# %%
# Create a Matplotlib figure and specify the size of the figure.
plt.figure(figsize = (20, 20))

# Get the names of all classes/categories in UCF50.
all_classes_names = os.listdir('Dataset')

# Generate a list of 20 random values. The values will be between 0-50,
# where 50 is the total number of class in the dataset.
# random_range = random.sample(range(len(all_classes_names)), len(all_classes_names))

# Iterating through all the generated random values.
for counter, random_index in enumerate(range(len(all_classes_names)), 1):

    # Retrieve a Class Name using the Random Index.
    selected_class_Name = all_classes_names[random_index]

    # Retrieve the list of all the video files present in the randomly selected Class Directory.
    video_files_names_list = os.listdir(f'Dataset/{selected_class_Name}')

    # Randomly select a video file from the list retrieved from the randomly selected Class Directory.
    selected_video_file_name = random.choice(video_files_names_list)

    # Initialize a VideoCapture object to read from the video File.
    video_reader = cv2.VideoCapture(f'Dataset/{selected_class_Name}/{selected_video_file_name}')
    video_reader.set(1, 25)

    # Read the first frame of the video file.
    _, bgr_frame = video_reader.read()

    bgr_frame = cv2.resize(bgr_frame ,(224,224))
    # Release the VideoCapture object.
    video_reader.release()

    # Convert the frame from BGR into RGB format.
    rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)

    # Write the class name on the video frame.
    cv2.putText(rgb_frame, selected_class_Name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 200, 255), 2)

    # Display the frame.
    plt.subplot(5, 4, counter);plt.imshow(rgb_frame);plt.axis('off')

# %% [markdown]
# # Set Dataset Variables

# %%
# Specify the height and width to which each video frame will be resized in our dataset.
IMAGE_HEIGHT , IMAGE_WIDTH = 64, 64

# Specify the number of frames of a video that will be fed to the model as one sequence.
SEQUENCE_LENGTH = 30

# Specify the directory containing the UCF50 dataset.
DATASET_DIR = "Dataset"

# Specify the list containing the names of the classes used for training. Feel free to choose any set of classes.
CLASSES_LIST = ["burglary", "fighting", "accident","explosion","shooting"]

# %% [markdown]
# # Data pre-processing

# %%
def frames_extraction(video_path):
    '''
    This function will extract the required frames from a video after resizing and normalizing them.
    Args:
        video_path: The path of the video in the disk, whose frames are to be extracted.
    Returns:
        frames_list: A list containing the resized and normalized frames of the video.
    '''

    # Declare a list to store video frames.
    frames_list = []

    # Read the Video File using the VideoCapture object.
    video_reader = cv2.VideoCapture(video_path)

    # Get the total number of frames in the video.
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the the interval after which frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

    # Iterate through the Video Frames.
    for frame_counter in range(SEQUENCE_LENGTH):

        # Set the current frame position of the video.
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)

        # Reading the frame from the video.
        success, frame = video_reader.read()

        # Check if Video frame is not successfully read then break the loop
        if not success:
            break

        # Resize the Frame to fixed height and width.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))

        # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1
        normalized_frame = resized_frame / 255

        # Append the normalized frame into the frames list
        frames_list.append(normalized_frame)

    # Release the VideoCapture object.
    video_reader.release()

    # Return the frames list.
    return frames_list

# %%
def create_dataset():
    '''
    This function will extract the data of the selected classes and create the required dataset.
    Returns:
        features:          A list containing the extracted frames of the videos.
        labels:            A list containing the indexes of the classes associated with the videos.
        video_files_paths: A list containing the paths of the videos in the disk.
    '''

    # Declared Empty Lists to store the features, labels and video file path values.
    features = []
    labels = []
    video_files_paths = []

    # Iterating through all the classes mentioned in the classes list
    for class_index, class_name in enumerate(CLASSES_LIST):

        # Display the name of the class whose data is being extracted.
        print(f'Extracting Data of Class: {class_name}')

        # Get the list of video files present in the specific class name directory.
        files_list = os.listdir(os.path.join(DATASET_DIR, class_name))

        # Iterate through all the files present in the files list.
        for file_name in files_list:

            # Get the complete video path.
            video_file_path = os.path.join(DATASET_DIR, class_name, file_name)

            # Extract the frames of the video file.
            frames = frames_extraction(video_file_path)

            # Check if the extracted frames are equal to the SEQUENCE_LENGTH specified above.
            # So ignore the vides having frames less than the SEQUENCE_LENGTH.
            if len(frames) == SEQUENCE_LENGTH:

                # Append the data to their repective lists.
                features.append(frames)
                labels.append(class_index)
                video_files_paths.append(video_file_path)

    # Converting the list to numpy arrays
    features = np.asarray(features)
    labels = np.array(labels)

    # Return the frames, class index, and video file path.
    return features, labels, video_files_paths

# %%
# Create the dataset.
features, labels, video_files_paths = create_dataset()
# Out:
# Extracting Data of Class: burglary
# Extracting Data of Class: fighting
# Extracting Data of Class: accident
# Extracting Data of Class: explosion
# Extracting Data of Class: shooting

# %%
# Using Keras's to_categorical method to convert labels into one-hot-encoded vectors
one_hot_encoded_labels = to_categorical(labels)

# %%
# Split the Data into Train ( 75% ) and Test Set ( 25% ).
features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels, test_size = 0.25, shuffle = True, random_state = seed_constant)
features = None
labels = None

# %% [markdown]
# # Model Creation LRCN (Long-term Recurrent Convolutional Network)

# %%
def create_LRCN_model():
    '''
    This function will construct the required LRCN model.
    Returns:
        model: It is the required constructed LRCN model.
    '''

    # We will use a Sequential model for model construction.
    model = Sequential()

    # Define the Model Architecture.
    ########################################################################################################################

    model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same',activation = 'relu'), input_shape = (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
    model.add(TimeDistributed(MaxPooling2D((4, 4))))

    model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((4, 4))))

    model.add(TimeDistributed(Conv2D(128, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))

    model.add(TimeDistributed(Conv2D(256, (2, 2), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))

    model.add(TimeDistributed(Flatten()))

    model.add(LSTM(32))

    model.add(Dense(len(CLASSES_LIST), activation = 'softmax'))

    ########################################################################################################################

    # Display the models summary.
    model.summary()

    # Return the constructed LRCN model.
    return model

# %%
model = create_LRCN_model()
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/keras/src/layers/core/wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed                │ (None, 30, 64, 64, 32) │           896 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 30, 16, 16, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_2              │ (None, 30, 16, 16, 64) │        18,496 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_3              │ (None, 30, 4, 4, 64)   │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_4              │ (None, 30, 4, 4, 128)  │        73,856 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_5              │ (None, 30, 2, 2, 128)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_6              │ (None, 30, 2, 2, 256)  │       131,328 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_7              │ (None, 30, 1, 1, 256)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_8              │ (None, 30, 256)        │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 32)             │        36,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 5)              │           165 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 261,733 (1022.39 KB)
#  Trainable params: 261,733 (1022.39 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
plot_model(model, to_file = 'Suspicious_Human_Activity_LRCN_Model.png', show_shapes = True, show_layer_names = True)

# %% [markdown]
# # Model Training

# %%
# Create an Instance of Early Stopping Callback.
early_stopping_callback = EarlyStopping(monitor = 'accuracy', patience = 10, mode = 'max', restore_best_weights = True)

# Compile the model and specify loss function, optimizer and metrics to the model.
model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])

# Start training the model.
model_training_history = model.fit(x = features_train, y = labels_train, epochs = 70, batch_size = 4 , shuffle = True, validation_split = 0.25, callbacks = [early_stopping_callback])
# Out:
# Epoch 1/70
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 98ms/step - accuracy: 0.3170 - loss: 1.4890 - val_accuracy: 0.7778 - val_loss: 0.5605
# Epoch 2/70
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - accuracy: 0.7867 - loss: 0.5836 - val_accuracy: 0.7020 - val_loss: 0.7207
# Epoch 3/70
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 20s 70ms/step - accuracy: 0.8624 - loss: 0.4450 - val_accuracy: 0.9798 - val_loss: 0.1314
# Epoch 4/70
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 21s 71ms/step - accuracy: 0.9495 - loss: 0.1367 - val_accuracy: 0.9293 - val_loss: 0.2820
# Epoch 5/70
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 20s 69ms/step - accuracy: 0.9054 - loss: 0.2374 - val_accuracy: 0.9596 - val_loss: 0.1643
# Epoch 6/70
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 20s 69ms/step - accuracy: 0.9873 - loss: 0.0717 - val_accuracy: 0.9646 - val_loss: 0.1280
# Epoch 7/70
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 21s 72ms/step - accuracy: 0.9534 - loss: 0.1103 - val_accuracy: 0.9596 - val_loss: 0.2146
# Epoch 8/70
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 19s 65ms/step - accuracy: 0.9852 - loss: 0.0670 - val_accuracy: 0.9848 - val_loss: 0.0596
# Epoch 9/70
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - accuracy: 0.9993 - loss: 0.0092 - val_accuracy: 0.9848 - val_loss: 0.0771
# Epoch 10/70
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.9928 - loss: 0.0198 - val_accuracy: 0.9848 - val_loss: 0.0814
# Epoch 11/70
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9848 - val_loss: 0.0973
# Epoch 12/70
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9848 - val_loss: 0.0997
# Epoch 13/70
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 20s 68ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9848 - val_loss: 0.0921
# Epoch 14/70
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9848 - val_loss: 0.0942
# Epoch 15/70
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9848 - val_loss: 0.0945
# Epoch 16/70
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 20s 68ms/step - accuracy: 1.0000 - loss: 8.5301e-04 - val_accuracy: 0.9848 - val_loss: 0.0771
# Epoch 17/70
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 1.0000 - loss: 7.3819e-04 - val_accuracy: 0.9848 - val_loss: 0.0879
# Epoch 18/70
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 1.0000 - loss: 6.5787e-04 - val_accuracy: 0.9848 - val_loss: 0.0926
# Epoch 19/70
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 1.0000 - loss: 6.1355e-04 - val_accuracy: 0.9848 - val_loss: 0.1061
# Epoch 20/70
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 1.0000 - loss: 5.7591e-04 - val_accuracy: 0.9848 - val_loss: 0.0980
# Epoch 21/70
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 20s 69ms/step - accuracy: 1.0000 - loss: 5.3710e-04 - val_accuracy: 0.9848 - val_loss: 0.0869

# %% [markdown]
# # Save Model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model.save("/content/drive/MyDrive/Suspicious_Human_Activity_Detection_LRCN_Model.keras")

# %%
# Save your Model.
model.save("Suspicious_Human_Activity_Detection_LRCN_Model.keras")

# %% [markdown]
# # Plot Loss and Accuracy Graphs while Training

# %%
def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name):
    '''
    This function will plot the metrics passed to it in a graph.
    Args:
        model_training_history: A history object containing a record of training and validation
                                loss values and metrics values at successive epochs
        metric_name_1:          The name of the first metric that needs to be plotted in the graph.
        metric_name_2:          The name of the second metric that needs to be plotted in the graph.
        plot_name:              The title of the graph.
    '''

    # Get metric values using metric names as identifiers.
    metric_value_1 = model_training_history.history[metric_name_1]
    metric_value_2 = model_training_history.history[metric_name_2]

    # Construct a range object which will be used as x-axis (horizontal plane) of the graph.
    epochs = range(len(metric_value_1))

    # Plot the Graph.
    plt.plot(epochs, metric_value_1, 'blue', label = metric_name_1)
    plt.plot(epochs, metric_value_2, 'red', label = metric_name_2)

    # Add title to the plot.
    plt.title(str(plot_name))

    # Add legend to the plot.
    plt.legend()

# %%
plot_metric(model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
plot_metric(model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')

# %% [markdown]
# # Accuracy on Test Dataset

# %%
# Calculate Accuracy On Test Dataset
acc = 0
for i in range(len(features_test)):
  predicted_label = np.argmax(model.predict(np.expand_dims(features_test[i],axis =0))[0])
  actual_label = np.argmax(labels_test[i])
  if predicted_label == actual_label:
      acc += 1
acc = (acc * 100)/len(labels_test)
print("Accuracy =",acc)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Accuracy = 100.0
